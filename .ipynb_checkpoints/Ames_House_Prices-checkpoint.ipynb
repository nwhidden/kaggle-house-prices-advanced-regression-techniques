# %% [markdown]
# # House Prices: Advanced Regression Techniques

# %% [markdown]
# __Excerpt from competition page__<br>
# ...With 79 explanatory variables describing (almost) every aspect of residential homes in Ames, Iowa, this competition challenges you to predict the final price of each home.
#
# __Practice Skills:__
# -  Creative feature engineering
# -  Advanced regression techniques like random forest and gradient boosting

# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Setup-and-Import" data-toc-modified-id="Setup-and-Import-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Setup and Import</a></span><ul class="toc-item"><li><span><a href="#Import" data-toc-modified-id="Import-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Import</a></span></li><li><span><a href="#Utility-Functions" data-toc-modified-id="Utility-Functions-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Utility Functions</a></span></li><li><span><a href="#High-Level-View" data-toc-modified-id="High-Level-View-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>High Level View</a></span></li><li><span><a href="#Data-Cleaning" data-toc-modified-id="Data-Cleaning-1.4"><span class="toc-item-num">1.4&nbsp;&nbsp;</span>Data Cleaning</a></span><ul class="toc-item"><li><span><a href="#Fix-NA-Import" data-toc-modified-id="Fix-NA-Import-1.4.1"><span class="toc-item-num">1.4.1&nbsp;&nbsp;</span>Fix NA Import</a></span></li></ul></li><li><span><a href="#Data-Preprocessing" data-toc-modified-id="Data-Preprocessing-1.5"><span class="toc-item-num">1.5&nbsp;&nbsp;</span>Data Preprocessing</a></span><ul class="toc-item"><li><span><a href="#Missing-Data" data-toc-modified-id="Missing-Data-1.5.1"><span class="toc-item-num">1.5.1&nbsp;&nbsp;</span>Missing Data</a></span></li></ul></li><li><span><a href="#Encode-Categorical-Data" data-toc-modified-id="Encode-Categorical-Data-1.6"><span class="toc-item-num">1.6&nbsp;&nbsp;</span>Encode Categorical Data</a></span></li><li><span><a href="#Normalization" data-toc-modified-id="Normalization-1.7"><span class="toc-item-num">1.7&nbsp;&nbsp;</span>Normalization</a></span></li></ul></li><li><span><a href="#EDA" data-toc-modified-id="EDA-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>EDA</a></span></li><li><span><a href="#Feature-Engineering" data-toc-modified-id="Feature-Engineering-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Feature Engineering</a></span></li><li><span><a href="#Simple-Model-Generation-and-Comparison" data-toc-modified-id="Simple-Model-Generation-and-Comparison-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Simple Model Generation and Comparison</a></span></li></ul></div>

# %% [markdown]
# ## Setup and Import

# %% [markdown]
# ### Import

# %%
#Imports
import numpy as np
import pandas as pd
import missingno as msno
import matplotlib.pyplot as plt
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import seaborn as sns

pd.set_option("display.max_columns",100)
train_data = pd.read_csv('train.csv')
test_data = pd.read_csv('test.csv')
y_train = train_data["SalePrice"]

# %% [markdown]
# ### Utility Functions

# %%
def plot_ann_barh(series, xlim=None, title=None, size=(12,6)):
    """Return axes for a barh chart from pandas Series"""
    #required imports
    import matplotlib.pyplot as plt
    import seaborn as sns
    
    #setup default values when necessary
    if xlim == None: xlim=series.max()
    if title == None: 
        if series.name == None: title='Title is required'
        else: title=series.name
    
    #create barchart
    ax = series.plot(kind='barh', title=title, xlim=(0,xlim), figsize=size, grid=False)
    sns.despine(left=True)
    
    #add annotations
    for i in ax.patches:
        # get_width pulls left or right; get_y pushes up or down
        ax.text(i.get_width()+(xlim*0.01), i.get_y()+.38, \
                str(i.get_width()), fontsize=10,
    color='dimgrey')
    
    #the invert will order the data as it is in the provided pandas Series
    plt.gca().invert_yaxis()
    
    return ax

# %% [markdown]
# ### High Level View

# %% [markdown]
# Will combine train/test sets into single dataframe for data cleaning and missing value imputation steps. Then will split them back out later.

# %%
test_data_idx = len(train_data)
combined_df = pd.concat([train_data.set_index("Id").drop("SalePrice", axis=1),test_data.set_index("Id")])
quantitative = [f for f in combined_df.columns if combined_df.dtypes[f] != 'object']
qualitative = [f for f in combined_df.columns if combined_df.dtypes[f] == 'object']

# %%
print("Training set has {:d} rows and {:d} features.".format(train_data.shape[0],train_data.shape[1]))
print("Test set has {:d} rows and {:d} features.".format(test_data.shape[0],test_data.shape[1]))
print("Combined set has {:d} rows and {:d} features.".format(combined_df.shape[0],combined_df.shape[1]))
print("Quantitative features: ")
print(quantitative)
print("Qualitative features: ")
print(qualitative)
# Out:
# Training set has 1460 rows and 81 features.
# Test set has 1459 rows and 80 features.
# Combined set has 2919 rows and 79 features.
# Quantitative features:
# ['MSSubClass', 'LotFrontage', 'LotArea', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd', 'MasVnrArea', 'BsmtFinSF1', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'TotRmsAbvGrd', 'Fireplaces', 'GarageYrBlt', 'GarageCars', 'GarageArea', 'WoodDeckSF', 'OpenPorchSF', 'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'MiscVal', 'MoSold', 'YrSold']
# Qualitative features:
# ['MSZoning', 'Street', 'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig', 'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType', 'HouseStyle', 'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2', 'Heating', 'HeatingQC', 'CentralAir', 'Electrical', 'KitchenQual', 'Functional', 'FireplaceQu', 'GarageType', 'GarageFinish', 'GarageQual', 'GarageCond', 'PavedDrive', 'PoolQC', 'Fence', 'MiscFeature', 'SaleType', 'SaleCondition']

# %% [markdown]
# ### Data Cleaning

# %% [markdown]
# #### Fix NA Import

# %% [markdown]
# "NA" is used in many features to specify the property doesn't have that feature (ex. PoolQC = NA means "No Pool". But Pandas interprets NA as missing data (NaN)). So let's rename them...

# %%
valid_na_features = ["Alley", 
                     "BsmtQual", "BsmtCond", "BsmtExposure", "BsmtFinType1", "BsmtFinType2", 
                     "FireplaceQu", 
                     "GarageType","GarageFinish", "GarageQual", "GarageCond", 
                     "PoolQC", 
                     "Fence",
                     "MiscFeature"]
na_feature_replace = ["NoAlley", 
                     "NoBsmt", "NoBsmt", "NoBsmt", "NoBsmt", "NoBsmt", 
                     "NoFireplace", 
                     "NoGarage","NoGarage", "NoGarage", "NoGarage", 
                     "NoPool", 
                     "NoFence",
                     "NoMiscFeature"]
for col,ft_replace in zip(valid_na_features,na_feature_replace):
    combined_df[col].fillna(ft_replace, inplace = True)
    combined_df[col].fillna(ft_replace, inplace = True)

# %% [markdown]
# ### Data Preprocessing

# %% [markdown]
# #### Missing Data

# %%
# Show distribution of missing data
msno.matrix(combined_df)

# %% [markdown]
# Not bad...

# %%
missing_cnt = combined_df.isnull().sum()
# Show only columns with non-zero null counts
missing = missing_cnt[missing_cnt > 0] 
# plot series result
ax = plot_ann_barh(missing.sort_values(ascending=False), 
                   xlim=max(missing), title='Count of Null values for each columns')

# %% [markdown]
# LotFrontage has the highest # of missing values, will deal with this one last. Most of the others can be imputed easily.

# %%
# BsmtUnfSF, BsmtFinSF2, TotalBsmtSF, BsmtFinSF1
combined_df.loc[combined_df[["BsmtUnfSF","BsmtFinSF2","TotalBsmtSF","BsmtFinSF1","BsmtFullBath","BsmtHalfBath"]].isnull().any(axis=1),:]
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street    Alley LotShape  \
# Id
# 2121          20       RM         99.0     5940   Pave  NoAlley      IR1
# 2189          20       RL        123.0    47007   Pave  NoAlley      IR1
#
#      LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# Id
# 2121         Lvl    AllPub       FR3       Gtl      BrkSide      Feedr
# 2189         Lvl    AllPub    Inside       Gtl      Edwards       Norm
#
#      Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# Id
# 2121       Norm     1Fam     1Story            4            7       1946
# 2189       Norm     1Fam     1Story            5            7       1959
#
#       YearRemodAdd RoofStyle RoofMatl Exterior1st Exterior2nd MasVnrType  \
# Id
# 2121          1950     Gable  CompShg     MetalSd      CBlock       None
# 2189          1996     Gable  CompShg     Plywood     Plywood       None
#
#       MasVnrArea ExterQual ExterCond Foundation BsmtQual BsmtCond  \
# Id
# 2121         0.0        TA        TA      PConc   NoBsmt   NoBsmt
# 2189         0.0        TA        TA       Slab   NoBsmt   NoBsmt
#
#      BsmtExposure BsmtFinType1  BsmtFinSF1 BsmtFinType2  BsmtFinSF2  \
# Id
# 2121       NoBsmt       NoBsmt         NaN       NoBsmt         NaN
# 2189       NoBsmt       NoBsmt         0.0       NoBsmt         0.0
#
#       BsmtUnfSF  TotalBsmtSF Heating HeatingQC CentralAir Electrical  \
# Id
# 2121        NaN          NaN    GasA        TA          Y      FuseA
# 2189        0.0          0.0    GasA        TA          Y      SBrkr
#
#       1stFlrSF  2ndFlrSF  LowQualFinSF  GrLivArea  BsmtFullBath  BsmtHalfBath  \
# Id
# 2121       896         0             0        896           NaN           NaN
# 2189      3820         0             0       3820           NaN           NaN
#
#       FullBath  HalfBath  BedroomAbvGr  KitchenAbvGr KitchenQual  \
# Id
# 2121         1         0             2             1          TA
# 2189         3         1             5             1          Ex
#
#       TotRmsAbvGrd Functional  Fireplaces  FireplaceQu GarageType  \
# Id
# 2121             4        Typ           0  NoFireplace     Detchd
# 2189            11        Typ           2           Gd     Attchd
#
#       GarageYrBlt GarageFinish  GarageCars  GarageArea GarageQual GarageCond  \
# Id
# 2121       1946.0          Unf         1.0       280.0         TA         TA
# 2189       1959.0          Unf         2.0       624.0         TA         TA
#
#      PavedDrive  WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  \
# Id
# 2121          Y           0            0              0          0
# 2189          Y           0          372              0          0
#
#       ScreenPorch  PoolArea  PoolQC    Fence    MiscFeature  MiscVal  MoSold  \
# Id
# 2121            0         0  NoPool    MnPrv  NoMiscFeature        0       4
# 2189            0         0  NoPool  NoFence  NoMiscFeature        0       7
#
#       YrSold SaleType SaleCondition
# Id
# 2121    2008    ConLD       Abnorml
# 2189    2008       WD        Normal

# %%
# 2 properties with basement features need to be imputed; both don't have a basement, so that's easy!
combined_df["BsmtUnfSF"].fillna(0, inplace=True)
combined_df["BsmtFinSF1"].fillna(0, inplace=True)
combined_df["BsmtFinSF2"].fillna(0, inplace=True)
combined_df["TotalBsmtSF"].fillna(0, inplace=True)
combined_df["BsmtFullBath"].fillna(0, inplace=True)
combined_df["BsmtHalfBath"].fillna(0, inplace=True)
# check the result
#combined_df.loc[combined_df[["BsmtUnfSF","BsmtFinSF2","TotalBsmtSF","BsmtFinSF1","BsmtFullBath","BsmtHalfBath"]].isnull().any(axis=1),:]

# %%
# GarageCars, GarageArea
combined_df.loc[combined_df[["GarageCars","GarageArea"]].isnull().any(axis=1),:]
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street    Alley LotShape  \
# Id
# 2577          70       RM         50.0     9060   Pave  NoAlley      Reg
#
#      LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# Id
# 2577         Lvl    AllPub    Inside       Gtl       IDOTRR       Norm
#
#      Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# Id
# 2577       Norm     1Fam     2Story            5            6       1923
#
#       YearRemodAdd RoofStyle RoofMatl Exterior1st Exterior2nd MasVnrType  \
# Id
# 2577          1999     Gable  CompShg     Wd Sdng     Plywood       None
#
#       MasVnrArea ExterQual ExterCond Foundation BsmtQual BsmtCond  \
# Id
# 2577         0.0        TA        TA     BrkTil       Gd       TA
#
#      BsmtExposure BsmtFinType1  BsmtFinSF1 BsmtFinType2  BsmtFinSF2  \
# Id
# 2577           No          ALQ       548.0          Unf         0.0
#
#       BsmtUnfSF  TotalBsmtSF Heating HeatingQC CentralAir Electrical  \
# Id
# 2577      311.0        859.0    GasA        Ex          Y      SBrkr
#
#       1stFlrSF  2ndFlrSF  LowQualFinSF  GrLivArea  BsmtFullBath  BsmtHalfBath  \
# Id
# 2577       942       886             0       1828           0.0           0.0
#
#       FullBath  HalfBath  BedroomAbvGr  KitchenAbvGr KitchenQual  \
# Id
# 2577         2         0             3             1          Gd
#
#       TotRmsAbvGrd Functional  Fireplaces  FireplaceQu GarageType  \
# Id
# 2577             6        Typ           0  NoFireplace     Detchd
#
#       GarageYrBlt GarageFinish  GarageCars  GarageArea GarageQual GarageCond  \
# Id
# 2577          NaN     NoGarage         NaN         NaN   NoGarage   NoGarage
#
#      PavedDrive  WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  \
# Id
# 2577          Y         174            0            212          0
#
#       ScreenPorch  PoolArea  PoolQC  Fence    MiscFeature  MiscVal  MoSold  \
# Id
# 2577            0         0  NoPool  MnPrv  NoMiscFeature        0       3
#
#       YrSold SaleType SaleCondition
# Id
# 2577    2007       WD        Alloca

# %%
# The property doesn't have a garage but GarageType is set to detached. Need to fix this one also.
# Should scrub the entire dataset and make sure other features aren't labeled incorrectly like this.
combined_df.loc[combined_df[["GarageCars","GarageArea"]].isnull().any(axis=1),"GarageType"] = "NoGarage"
combined_df["GarageCars"].fillna(0, inplace=True)
combined_df["GarageArea"].fillna(0, inplace=True)
#combined_df.loc[combined_df[["GarageCars","GarageArea"]].isnull().any(axis=1),:]

# %%
# KitchenQual
combined_df.loc[combined_df["KitchenQual"].isnull(),:]
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street    Alley LotShape  \
# Id
# 1556          50       RL         72.0    10632   Pave  NoAlley      IR1
#
#      LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# Id
# 1556         Lvl    AllPub    Inside       Gtl      ClearCr       Norm
#
#      Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# Id
# 1556       Norm     1Fam     1.5Fin            5            3       1917
#
#       YearRemodAdd RoofStyle RoofMatl Exterior1st Exterior2nd MasVnrType  \
# Id
# 1556          1950     Gable  CompShg     Wd Sdng     Wd Sdng       None
#
#       MasVnrArea ExterQual ExterCond Foundation BsmtQual BsmtCond  \
# Id
# 1556         0.0        TA        TA     BrkTil       Gd       Fa
#
#      BsmtExposure BsmtFinType1  BsmtFinSF1 BsmtFinType2  BsmtFinSF2  \
# Id
# 1556           No          Unf         0.0          Unf         0.0
#
#       BsmtUnfSF  TotalBsmtSF Heating HeatingQC CentralAir Electrical  \
# Id
# 1556      689.0        689.0    GasA        Gd          N      SBrkr
#
#       1stFlrSF  2ndFlrSF  LowQualFinSF  GrLivArea  BsmtFullBath  BsmtHalfBath  \
# Id
# 1556       725       499             0       1224           0.0           0.0
#
#       FullBath  HalfBath  BedroomAbvGr  KitchenAbvGr KitchenQual  \
# Id
# 1556         1         1             3             1         NaN
#
#       TotRmsAbvGrd Functional  Fireplaces  FireplaceQu GarageType  \
# Id
# 1556             6        Mod           0  NoFireplace     Detchd
#
#       GarageYrBlt GarageFinish  GarageCars  GarageArea GarageQual GarageCond  \
# Id
# 1556       1917.0          Unf         1.0       180.0         Fa         Fa
#
#      PavedDrive  WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  \
# Id
# 1556          N           0            0            248          0
#
#       ScreenPorch  PoolArea  PoolQC    Fence    MiscFeature  MiscVal  MoSold  \
# Id
# 1556            0         0  NoPool  NoFence  NoMiscFeature        0       1
#
#       YrSold SaleType SaleCondition
# Id
# 1556    2010      COD        Normal

# %%
# look at other properties in the same neighborhood with same overall quality to impute KitchenQual
combined_df.loc[(combined_df["Neighborhood"] == "ClearCr") & 
                (combined_df["OverallQual"].between(4,6)) & 
                (combined_df["YearRemodAdd"].between(1945,1960)),
                ("OverallQual","OverallCond","YearRemodAdd","KitchenQual","GarageQual","ExterQual","BsmtQual","FireplaceQu","PoolQC","Fence")]
# Out:
#       OverallQual  OverallCond  YearRemodAdd KitchenQual GarageQual ExterQual  \
# Id
# 359             5            4          1958          Gd         TA        TA
# 372             4            4          1959          TA         TA        TA
# 1555            5            5          1959          TA         TA        TA
# 1556            5            3          1950         NaN         Fa        TA
# 1847            5            5          1956          TA         TA        TA
# 2147            5            3          1960          TA         TA        TA
#
#      BsmtQual  FireplaceQu  PoolQC    Fence
# Id
# 359        TA  NoFireplace  NoPool  NoFence
# 372    NoBsmt           Gd  NoPool  NoFence
# 1555       Gd           Gd  NoPool  NoFence
# 1556       Gd  NoFireplace  NoPool  NoFence
# 1847       TA           TA  NoPool  NoFence
# 2147       TA           TA  NoPool  NoFence

# %%
# Most properties similar to this based on the matching criteria are in Gd/TA quality. Choose TA since that's more typical.
combined_df["KitchenQual"].fillna("TA", inplace = True)

# %%
# SaleType
combined_df.loc[combined_df["SaleType"].isnull(),:]
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street    Alley LotShape  \
# Id
# 2490          20       RL         85.0    13770   Pave  NoAlley      Reg
#
#      LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# Id
# 2490         Lvl    AllPub    Corner       Gtl       Sawyer      Feedr
#
#      Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# Id
# 2490       Norm     1Fam     1Story            5            6       1958
#
#       YearRemodAdd RoofStyle RoofMatl Exterior1st Exterior2nd MasVnrType  \
# Id
# 2490          1998     Gable  CompShg     Plywood     Plywood    BrkFace
#
#       MasVnrArea ExterQual ExterCond Foundation BsmtQual BsmtCond  \
# Id
# 2490       340.0        TA        TA     CBlock       TA       TA
#
#      BsmtExposure BsmtFinType1  BsmtFinSF1 BsmtFinType2  BsmtFinSF2  \
# Id
# 2490           Mn          Rec       190.0          BLQ       873.0
#
#       BsmtUnfSF  TotalBsmtSF Heating HeatingQC CentralAir Electrical  \
# Id
# 2490       95.0       1158.0    GasA        TA          Y      SBrkr
#
#       1stFlrSF  2ndFlrSF  LowQualFinSF  GrLivArea  BsmtFullBath  BsmtHalfBath  \
# Id
# 2490      1176         0             0       1176           1.0           0.0
#
#       FullBath  HalfBath  BedroomAbvGr  KitchenAbvGr KitchenQual  \
# Id
# 2490         1         0             3             1          TA
#
#       TotRmsAbvGrd Functional  Fireplaces FireplaceQu GarageType  GarageYrBlt  \
# Id
# 2490             6        Typ           2          Gd     Attchd       1958.0
#
#      GarageFinish  GarageCars  GarageArea GarageQual GarageCond PavedDrive  \
# Id
# 2490          Unf         1.0       303.0         TA         TA          Y
#
#       WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  ScreenPorch  \
# Id
# 2490           0            0              0          0            0
#
#       PoolArea  PoolQC    Fence    MiscFeature  MiscVal  MoSold  YrSold  \
# Id
# 2490         0  NoPool  NoFence  NoMiscFeature        0      10    2007
#
#      SaleType SaleCondition
# Id
# 2490      NaN        Normal

# %%
# Check out other properties sold in same year
combined_df.loc[combined_df["YrSold"] == 2007,"SaleType"].value_counts()
# Out:
# WD       568
# New       89
# COD       18
# CWD       11
# Oth        2
# ConLw      2
# Con        1
# Name: SaleType, dtype: int64

# %%
# Check out the "other" saletypes for fun... Maybe the NaN should be Other...
combined_df.loc[(combined_df["YrSold"] == 2007) & (combined_df["SaleType"] == "Oth"),:]
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street    Alley LotShape  \
# Id
# 943           90       RL         42.0     7711   Pave  NoAlley      IR1
# 1132          20       RL         63.0    10712   Pave  NoAlley      Reg
#
#      LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# Id
# 943          Lvl    AllPub    Inside       Gtl      Edwards       Norm
# 1132         Lvl    AllPub    Inside       Gtl      Mitchel       Norm
#
#      Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# Id
# 943        Norm   Duplex     1Story            4            3       1977
# 1132       Norm     1Fam     1Story            5            5       1991
#
#       YearRemodAdd RoofStyle RoofMatl Exterior1st Exterior2nd MasVnrType  \
# Id
# 943           1977     Gable  CompShg     MetalSd     MetalSd       None
# 1132          1992     Gable  CompShg     HdBoard     HdBoard       None
#
#       MasVnrArea ExterQual ExterCond Foundation BsmtQual BsmtCond  \
# Id
# 943          0.0        TA        TA      PConc       Gd       TA
# 1132         0.0        TA        TA      PConc       Gd       TA
#
#      BsmtExposure BsmtFinType1  BsmtFinSF1 BsmtFinType2  BsmtFinSF2  \
# Id
# 943            Gd          GLQ      1440.0          Unf         0.0
# 1132           Mn          BLQ       212.0          Unf         0.0
#
#       BsmtUnfSF  TotalBsmtSF Heating HeatingQC CentralAir Electrical  \
# Id
# 943         0.0       1440.0    GasA        TA          Y      SBrkr
# 1132      762.0        974.0    GasA        TA          Y      SBrkr
#
#       1stFlrSF  2ndFlrSF  LowQualFinSF  GrLivArea  BsmtFullBath  BsmtHalfBath  \
# Id
# 943       1440         0             0       1440           2.0           0.0
# 1132       974         0             0        974           0.0           0.0
#
#       FullBath  HalfBath  BedroomAbvGr  KitchenAbvGr KitchenQual  \
# Id
# 943          2         0             4             2          TA
# 1132         1         0             3             1          TA
#
#       TotRmsAbvGrd Functional  Fireplaces  FireplaceQu GarageType  \
# Id
# 943              8        Typ           0  NoFireplace   NoGarage
# 1132             5        Typ           0  NoFireplace   NoGarage
#
#       GarageYrBlt GarageFinish  GarageCars  GarageArea GarageQual GarageCond  \
# Id
# 943           NaN     NoGarage         0.0         0.0   NoGarage   NoGarage
# 1132          NaN     NoGarage         0.0         0.0   NoGarage   NoGarage
#
#      PavedDrive  WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  \
# Id
# 943           N         321            0              0          0
# 1132          Y           0           28              0          0
#
#       ScreenPorch  PoolArea  PoolQC    Fence    MiscFeature  MiscVal  MoSold  \
# Id
# 943             0         0  NoPool  NoFence  NoMiscFeature        0       8
# 1132            0         0  NoPool    MnPrv  NoMiscFeature        0       9
#
#       YrSold SaleType SaleCondition
# Id
# 943     2007      Oth       Abnorml
# 1132    2007      Oth       Abnorml

# %%
# Both "Other" saletypes are abnormal, while the NaN property has normal salecondition. Are all "other" saletypes abnormal?
combined_df.loc[combined_df["SaleType"] == "Oth","SaleCondition"].value_counts()
# Out:
# Abnorml    5
# Family     1
# Normal     1
# Name: SaleCondition, dtype: int64

# %%
# "Other" SaleType is pretty rare and most are "abnormal" SaleCondition. 
# Probably using the most common SaleType with Normal SaleCondition from 2007 would be best guess.
combined_df.loc[(combined_df["YrSold"] == 2007) & (combined_df["SaleCondition"] == "Normal"),"SaleType"].value_counts()
# Out:
# WD       529
# COD       11
# CWD       10
# Con        1
# ConLw      1
# Name: SaleType, dtype: int64

# %%
combined_df["SaleType"].fillna("WD", inplace = True)

# %%
# Exterior1st, Exterior2nd
combined_df.loc[combined_df[["Exterior1st","Exterior2nd"]].isnull().any(axis=1),:]
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street    Alley LotShape  \
# Id
# 2152          30       RL         85.0    19550   Pave  NoAlley      Reg
#
#      LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# Id
# 2152         Lvl    AllPub    Inside       Gtl      Edwards       Norm
#
#      Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# Id
# 2152       Norm     1Fam     1Story            5            7       1940
#
#       YearRemodAdd RoofStyle RoofMatl Exterior1st Exterior2nd MasVnrType  \
# Id
# 2152          2007      Flat  Tar&Grv         NaN         NaN       None
#
#       MasVnrArea ExterQual ExterCond Foundation BsmtQual BsmtCond  \
# Id
# 2152         0.0        TA        TA      PConc       TA       TA
#
#      BsmtExposure BsmtFinType1  BsmtFinSF1 BsmtFinType2  BsmtFinSF2  \
# Id
# 2152           Gd          ALQ      1035.0          Unf         0.0
#
#       BsmtUnfSF  TotalBsmtSF Heating HeatingQC CentralAir Electrical  \
# Id
# 2152      545.0       1580.0    GasA        Ex          Y      SBrkr
#
#       1stFlrSF  2ndFlrSF  LowQualFinSF  GrLivArea  BsmtFullBath  BsmtHalfBath  \
# Id
# 2152      1518         0             0       1518           1.0           0.0
#
#       FullBath  HalfBath  BedroomAbvGr  KitchenAbvGr KitchenQual  \
# Id
# 2152         1         0             2             1          Fa
#
#       TotRmsAbvGrd Functional  Fireplaces FireplaceQu GarageType  GarageYrBlt  \
# Id
# 2152             5        Typ           2          Gd   NoGarage          NaN
#
#      GarageFinish  GarageCars  GarageArea GarageQual GarageCond PavedDrive  \
# Id
# 2152     NoGarage         0.0         0.0   NoGarage   NoGarage          Y
#
#       WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  ScreenPorch  \
# Id
# 2152           0           39              0          0            0
#
#       PoolArea  PoolQC    Fence    MiscFeature  MiscVal  MoSold  YrSold  \
# Id
# 2152         0  NoPool  NoFence  NoMiscFeature        0       1    2008
#
#      SaleType SaleCondition
# Id
# 2152       WD        Normal

# %%
# OK, look at other houses in the neighborhood, built around same time, with a recent remodel
combined_df.loc[(combined_df["Neighborhood"] == "Edwards") &
                (combined_df["YearBuilt"].between(1935,1950)) &
                (combined_df["YearRemodAdd"] > 1995),:]
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street    Alley LotShape  \
# Id
# 166          190       RL         62.0    10106   Pave  NoAlley      Reg
# 176           20       RL         84.0    12615   Pave  NoAlley      Reg
# 293           50       RL         60.0    11409   Pave  NoAlley      Reg
# 554           20       RL         67.0     8777   Pave  NoAlley      Reg
# 608           20       RL         78.0     7800   Pave  NoAlley      Reg
# 1050          20       RL         60.0    11100   Pave  NoAlley      Reg
# 1124          20       RL         50.0     9405   Pave  NoAlley      Reg
# 1586          30       RL         67.0     8777   Pave  NoAlley      Reg
# 2152          30       RL         85.0    19550   Pave  NoAlley      Reg
# 2193          50       RL         60.0    12180   Pave  NoAlley      Reg
# 2493          20       RL          NaN    17541   Pave  NoAlley      IR1
#
#      LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# Id
# 166          Lvl    AllPub    Inside       Gtl      Edwards       Norm
# 176          Lvl    AllPub    Corner       Gtl      Edwards       Norm
# 293          Lvl    AllPub    Inside       Gtl      Edwards       Norm
# 554          Lvl    AllPub    Inside       Gtl      Edwards      Feedr
# 608          Bnk    AllPub    Inside       Mod      Edwards       Norm
# 1050         Low    AllPub    Inside       Gtl      Edwards       Norm
# 1124         Lvl    AllPub    Inside       Gtl      Edwards       Norm
# 1586         Lvl    AllPub    Inside       Mod      Edwards      Feedr
# 2152         Lvl    AllPub    Inside       Gtl      Edwards       Norm
# 2193         Lvl    AllPub    Inside       Gtl      Edwards       Norm
# 2493         Lvl    AllPub    Corner       Gtl      Edwards       Norm
#
#      Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# Id
# 166        Norm   2fmCon     1.5Fin            5            7       1940
# 176        Norm     1Fam     1Story            6            7       1950
# 293        Norm     1Fam     1.5Fin            5            4       1949
# 554        Norm     1Fam     1Story            4            5       1949
# 608        Norm     1Fam     2Story            5            8       1948
# 1050       Norm     1Fam     1Story            4            7       1946
# 1124       Norm     1Fam     1Story            5            9       1947
# 1586       Norm     1Fam     1Story            3            6       1945
# 2152       Norm     1Fam     1Story            5            7       1940
# 2193       Norm     1Fam     1.5Fin            5            7       1938
# 2493       Norm     1Fam     1Story            5            7       1948
#
#       YearRemodAdd RoofStyle RoofMatl Exterior1st Exterior2nd MasVnrType  \
# Id
# 166           1999     Gable  CompShg     Wd Sdng     Wd Sdng       None
# 176           2001     Gable  CompShg     WdShing     Wd Shng       None
# 293           2008     Gable  CompShg     Wd Sdng     Wd Sdng       None
# 554           2003     Gable  CompShg     VinylSd     VinylSd       None
# 608           2002     Gable  CompShg     MetalSd     MetalSd       None
# 1050          2006     Gable  CompShg     MetalSd     MetalSd       None
# 1124          2008       Hip  CompShg     VinylSd     VinylSd       None
# 1586          2007     Gable  CompShg     VinylSd     VinylSd       None
# 2152          2007      Flat  Tar&Grv         NaN         NaN       None
# 2193          2007     Gable  CompShg     Wd Sdng     Wd Sdng       None
# 2493          2005       Hip  CompShg     Wd Sdng     Wd Sdng       None
#
#       MasVnrArea ExterQual ExterCond Foundation BsmtQual BsmtCond  \
# Id
# 166          0.0        TA        Gd     BrkTil       TA       TA
# 176          0.0        TA        TA     CBlock       TA       Gd
# 293          0.0        TA        TA     CBlock       TA       TA
# 554          0.0        TA        TA     CBlock   NoBsmt   NoBsmt
# 608          0.0        TA        Gd     CBlock       TA       Gd
# 1050         0.0        TA        TA     CBlock   NoBsmt   NoBsmt
# 1124         0.0        TA        Ex     CBlock       TA       TA
# 1586         0.0        TA        Gd     CBlock   NoBsmt   NoBsmt
# 2152         0.0        TA        TA      PConc       TA       TA
# 2193         0.0        TA        TA      PConc       TA       TA
# 2493         0.0        TA        Gd     CBlock       TA       Gd
#
#      BsmtExposure BsmtFinType1  BsmtFinSF1 BsmtFinType2  BsmtFinSF2  \
# Id
#
0         TA         TA
#
#      PavedDrive  WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  \
# Id
# 166           Y         140            0              0          0
# 176           Y           0           29             39          0
# 293           Y           0            0              0          0
# 554           N           0           96              0          0
# 608           Y         103            0              0          0
# 1050          Y           0            0              0          0
# 1124          Y           0          200              0          0
# 1586          N           0            0              0          0
# 2152          Y           0           39              0          0
# 2193          N          42            0              0          0
# 2493          Y           0           42              0          0
#
#       ScreenPorch  PoolArea  PoolQC    Fence    MiscFeature  MiscVal  MoSold  \
# Id
# 166             0         0  NoPool  NoFence  NoMiscFeature        0       9
# 176             0         0  NoPool    MnPrv  NoMiscFeature        0       6
# 293           160         0  NoPool  NoFence  NoMiscFeature        0       1
# 554             0         0  NoPool    MnPrv  NoMiscFeature        0       5
# 608             0         0  NoPool  NoFence  NoMiscFeature        0       8
# 1050            0         0  NoPool  NoFence  NoMiscFeature        0       4
# 1124            0         0  NoPool  NoFence  NoMiscFeature        0       6
# 1586            0         0  NoPool  NoFence  NoMiscFeature        0       4
# 2152            0         0  NoPool  NoFence  NoMiscFeature        0       1
# 2193            0         0  NoPool  NoFence  NoMiscFeature        0       1
# 2493            0         0  NoPool  NoFence  NoMiscFeature        0       7
#
#       YrSold SaleType SaleCondition
# Id
# 166     2008       WD        Normal
# 176     2007       WD        Normal
# 293     2009       WD        Normal
# 554     2009       WD        Normal
# 608     2006       WD        Normal
# 1050    2010       WD       Abnorml
# 1124    2009       WD        Normal
# 1586    2010    ConLD        Normal
# 2152    2008       WD        Normal
# 2193    2008       WD        Family
# 2493    2007       WD        Normal

# %%
# What about with same rooftype...
#(combined_df["Neighborhood"] == "Edwards") &
#(combined_df["YearBuilt"].between(1935,1950)) &
                                

combined_df.loc[(combined_df["RoofStyle"] == "Flat") &
                (combined_df["RoofMatl"] == "Tar&Grv"),"Exterior2nd"].value_counts()
# Out:
# Plywood    8
# Wd Sdng    4
# Wd Shng    2
# CBlock     1
# Brk Cmn    1
# Name: Exterior2nd, dtype: int64

# %%
# Plywood is most common exterior for houses with this type of roof, so will go with that as best guess...
combined_df["Exterior1st"].fillna("Plywood", inplace = True)
combined_df["Exterior2nd"].fillna("Plywood", inplace = True)

# %%
# Utilities
combined_df.loc[combined_df[["Utilities"]].isnull().any(axis=1),:]
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street    Alley LotShape  \
# Id
# 1916          30      NaN        109.0    21780   Grvl  NoAlley      Reg
# 1946          20       RL          NaN    31220   Pave  NoAlley      IR1
#
#      LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# Id
# 1916         Lvl       NaN    Inside       Gtl       IDOTRR       Norm
# 1946         Bnk       NaN       FR2       Gtl      Gilbert      Feedr
#
#      Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# Id
# 1916       Norm     1Fam     1Story            2            4       1910
# 1946       Norm     1Fam     1Story            6            2       1952
#
#       YearRemodAdd RoofStyle RoofMatl Exterior1st Exterior2nd MasVnrType  \
# Id
# 1916          1950     Gable  CompShg     Wd Sdng     Wd Sdng       None
# 1946          1952       Hip  CompShg     BrkFace     BrkFace       None
#
#       MasVnrArea ExterQual ExterCond Foundation BsmtQual BsmtCond  \
# Id
# 1916         0.0        Fa        Fa     CBlock   NoBsmt   NoBsmt
# 1946         0.0        TA        TA     CBlock       TA       TA
#
#      BsmtExposure BsmtFinType1  BsmtFinSF1 BsmtFinType2  BsmtFinSF2  \
# Id
# 1916       NoBsmt       NoBsmt         0.0       NoBsmt         0.0
# 1946           No          Unf         0.0          Unf         0.0
#
#       BsmtUnfSF  TotalBsmtSF Heating HeatingQC CentralAir Electrical  \
# Id
# 1916        0.0          0.0    GasA        TA          N      FuseA
# 1946     1632.0       1632.0    GasA        TA          Y      FuseA
#
#       1stFlrSF  2ndFlrSF  LowQualFinSF  GrLivArea  BsmtFullBath  BsmtHalfBath  \
# Id
# 1916       810         0             0        810           0.0           0.0
# 1946      1474         0             0       1474           0.0           0.0
#
#       FullBath  HalfBath  BedroomAbvGr  KitchenAbvGr KitchenQual  \
# Id
# 1916         1         0             1             1          TA
# 1946         1         0             3             1          TA
#
#       TotRmsAbvGrd Functional  Fireplaces  FireplaceQu GarageType  \
# Id
# 1916             4       Min1           0  NoFireplace     Detchd
# 1946             7       Min2           2           Gd     Attchd
#
#       GarageYrBlt GarageFinish  GarageCars  GarageArea GarageQual GarageCond  \
# Id
# 1916       1975.0          Unf         1.0       280.0         TA         TA
# 1946       1952.0          Unf         2.0       495.0         TA         TA
#
#      PavedDrive  WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  \
# Id
# 1916          N         119           24              0          0
# 1946          Y           0            0            144          0
#
#       ScreenPorch  PoolArea  PoolQC    Fence    MiscFeature  MiscVal  MoSold  \
# Id
# 1916            0         0  NoPool  NoFence  NoMiscFeature        0       3
# 1946            0         0  NoPool  NoFence           Shed      750       5
#
#       YrSold SaleType SaleCondition
# Id
# 1916    2009    ConLD        Normal
# 1946    2008       WD        Normal

# %%
# Both have gas heating, 2nd has AC, both have electrical. Look at other houses in the neighborhoods.
print(combined_df.loc[(combined_df["Neighborhood"] == "IDOTRR"),"Utilities"].value_counts())
print(combined_df.loc[(combined_df["Neighborhood"] == "Gilbert"),"Utilities"].value_counts())
# Out:
# AllPub    92
# Name: Utilities, dtype: int64
# AllPub    164
# Name: Utilities, dtype: int64

# %%
# both neighborhoods have "AllPub" utilities for all properties, so impute with that value.
combined_df["Utilities"].fillna("AllPub", inplace = True)

# %%
# Functional
combined_df.loc[combined_df[["Functional"]].isnull().any(axis=1),:]
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street    Alley LotShape  \
# Id
# 2217          20      NaN         80.0    14584   Pave  NoAlley      Reg
# 2474          50       RM         60.0    10320   Pave     Grvl      Reg
#
#      LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# Id
# 2217         Low    AllPub    Inside       Mod       IDOTRR       Norm
# 2474         Lvl    AllPub    Corner       Gtl       IDOTRR     Artery
#
#      Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# Id
# 2217       Norm     1Fam     1Story            1            5       1952
# 2474       Norm     1Fam     1.5Fin            4            1       1910
#
#       YearRemodAdd RoofStyle RoofMatl Exterior1st Exterior2nd MasVnrType  \
# Id
# 2217          1952     Gable  CompShg     AsbShng     VinylSd       None
# 2474          1950     Gable  CompShg     Wd Sdng     Wd Sdng       None
#
#       MasVnrArea ExterQual ExterCond Foundation BsmtQual BsmtCond  \
# Id
# 2217         0.0        Fa        Po       Slab   NoBsmt   NoBsmt
# 2474         0.0        Fa        Fa     CBlock       TA       Fa
#
#      BsmtExposure BsmtFinType1  BsmtFinSF1 BsmtFinType2  BsmtFinSF2  \
# Id
# 2217       NoBsmt       NoBsmt         0.0       NoBsmt         0.0
# 2474           No          Unf         0.0          Unf         0.0
#
#       BsmtUnfSF  TotalBsmtSF Heating HeatingQC CentralAir Electrical  \
# Id
# 2217        0.0          0.0    Wall        Po          N      FuseA
# 2474      771.0        771.0    GasA        Fa          Y      SBrkr
#
#       1stFlrSF  2ndFlrSF  LowQualFinSF  GrLivArea  BsmtFullBath  BsmtHalfBath  \
# Id
# 2217       733         0             0        733           0.0           0.0
# 2474       866       504           114       1484           0.0           0.0
#
#       FullBath  HalfBath  BedroomAbvGr  KitchenAbvGr KitchenQual  \
# Id
# 2217         1         0             2             1          Fa
# 2474         2         0             3             1          TA
#
#       TotRmsAbvGrd Functional  Fireplaces  FireplaceQu GarageType  \
# Id
# 2217             4        NaN           0  NoFireplace     Attchd
# 2474             6        NaN           0  NoFireplace     Detchd
#
#       GarageYrBlt GarageFinish  GarageCars  GarageArea GarageQual GarageCond  \
# Id
# 2217       1952.0          Unf         2.0       487.0         Fa         Po
# 2474       1910.0          Unf         1.0       264.0         TA         Fa
#
#      PavedDrive  WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  \
# Id
# 2217          N           0            0              0          0
# 2474          N          14          211              0          0
#
#       ScreenPorch  PoolArea  PoolQC    Fence    MiscFeature  MiscVal  MoSold  \
# Id
# 2217            0         0  NoPool  NoFence  NoMiscFeature        0       2
# 2474           84         0  NoPool  NoFence  NoMiscFeature        0       9
#
#       YrSold SaleType SaleCondition
# Id
# 2217    2008       WD       Abnorml
# 2474    2007      COD       Abnorml

# %%
# both properties have abnormal salecondition so let's look at other properties w/ this condition.
combined_df.loc[(combined_df["SaleCondition"] == "Abnorml") & 
                (combined_df["OverallQual"].between(4,6)),
                ("Functional","SaleType","GarageQual","BsmtQual","ExterQual","OverallQual","OverallCond")]
# Out:
#      Functional SaleType GarageQual BsmtQual ExterQual  OverallQual  \
# Id
# 20         Min1      COD         TA       TA        TA            5
# 39          Typ       WD         TA       TA        TA            5
# 41          Typ       WD         TA       TA        TA            6
# 92          Typ       WD         TA       TA        TA            5
# 99          Typ      COD         Fa       TA        TA            5
# 114         Typ      COD         TA       Gd        TA            6
# 130         Typ       WD         TA       TA        TA            5
# 145         Typ    ConLI         TA       TA        TA            5
# 199         Typ       WD   NoGarage       TA        TA            6
# 224         Typ       WD         TA       TA        TA            4
# 226         Typ      COD         TA       TA        TA            5
# 304         Typ       WD         TA       TA        TA            5
# 359        Min2       WD         TA       TA        TA            5
# 388         Typ       WD         TA       TA        TA            6
# 394         Typ       WD   NoGarage       TA        TA            4
# 399        Maj2       WD         Po       Fa        TA            5
# 411         Mod      COD         TA       TA        TA            5
# 431         Typ      COD         TA       TA        TA            6
# 432         Typ    ConLD   NoGarage       TA        TA            6
# 457         Typ      COD         Fa       TA        TA            5
# 496         Typ       WD   NoGarage       TA        TA            4
# 517         Typ      COD         TA       TA        TA            6
# 531         Typ       WD         TA       Gd        Gd            6
# 551         Typ      COD         TA       Gd        TA            6
# 572         Typ       WD         TA       TA        TA            6
# 576         Typ      COD         TA       TA        TA            5
# 578         Typ       WD         TA       TA        TA            5
# 616         Typ       WD         TA       TA        TA            6
# 631         Typ       WD         Fa       Fa        TA            5
# 636         Typ       WD   NoGarage       TA        Fa            6
# ...         ...      ...        ...      ...       ...          ...
# 2269        Typ      COD         TA       Gd        TA            6
# 2364        Typ       WD         TA       Gd        TA            6
# 2426        Mod       WD         TA       TA        TA            4
# 2429        Typ      COD         TA       TA        TA            5
# 2448        Typ       WD         TA       TA        TA            6
# 2473        Typ      COD         TA       Fa        TA            4
# 2474        NaN      COD         TA       TA        Fa            4
# 2543        Typ       WD         TA       Gd        TA            5
# 2554        Typ       WD   NoGarage       TA        TA            5
# 2581        Typ       WD         TA       TA        TA            4
# 2611        Typ      COD         TA       TA        TA            4
# 2618       Min1       WD         TA       Gd        TA            6
# 2723        Typ       WD         TA       TA        TA            6
# 2727       Min1       WD         TA       TA        TA            6
# 2745        Typ       WD         TA       TA        TA            6
# 2760        Typ      COD         Fa       Fa        TA            4
# 2780        Typ      COD         TA       TA        TA            6
# 2798        Typ       WD         Fa       TA        TA            4
# 2800        Typ       WD   NoGarage       TA        TA            5
# 2810        Typ       WD         TA       TA        TA            5
# 2828        Typ       WD         TA       Gd        Gd            6
# 2837        Typ      COD         TA       Gd        TA            6
# 2861        Typ       WD         TA       Gd        TA            5
# 2870       Min1       WD         TA       TA        TA            4
# 2871        Typ      COD   NoGarage       TA        TA            4
# 2875        Typ       WD         TA       TA        TA            6
# 2893       Min2       WD   NoGarage       TA        Fa            5
# 2913        Typ       WD         TA       TA        TA            4
# 2916        Typ       WD         TA       TA        TA            4
# 2917        Typ       WD         TA       TA        TA            5
#
#       OverallCond
# Id
# 20              6
# 39              7
# 41              5
# 92              3
# 99              5
# 114             5
# 130             7
# 145             5
# 199             6
# 224             6
# 226             5
# 304             7
# 359             4
# 388             6
# 394             5
# 399             2
# 411             3
# 431             5
# 432             7
# 457             5
# 496             5
# 517             6
# 531             5
# 551             6
# 572             6
# 576             5
# 578             6
# 616             7
# 631             6
# 636             7
# ...           ...
# 2269            5
# 2364            7
# 2426            7
# 2429            7
# 2448            6
# 2473            6
# 2474            1
# 2543            5
# 2554            6
# 2581            6
# 2611            3
# 2618            6
# 2723            7
# 2727            7
# 2745            8
# 2760            4
# 2780            5
# 2798            5
# 2800            4
# 2810            6
# 2828            4
# 2837            5
# 2861            4
# 2870            4
# 2871            4
# 2875            6
# 2893            6
# 2913            5
# 2916            5
# 2917            7
#
# [146 rows x 7 columns]

# %%
combined_df.loc[(combined_df["SaleCondition"] == "Abnorml") & (combined_df["OverallQual"] < 6),"Functional"].value_counts()
# Out:
# Typ     92
# Min2     5
# Mod      4
# Min1     3
# Maj2     2
# Sev      1
# Name: Functional, dtype: int64

# %%
# Seems safe to use Typ for Imputing missing "functional" features
combined_df["Functional"].fillna("Typ", inplace = True)

# %%
# MsZoning
combined_df.loc[combined_df[["MSZoning"]].isnull().any(axis=1),:]
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street    Alley LotShape  \
# Id
# 1916          30      NaN        109.0    21780   Grvl  NoAlley      Reg
# 2217          20      NaN         80.0    14584   Pave  NoAlley      Reg
# 2251          70      NaN          NaN    56600   Pave  NoAlley      IR1
# 2905          20      NaN        125.0    31250   Pave  NoAlley      Reg
#
#      LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# Id
# 1916         Lvl    AllPub    Inside       Gtl       IDOTRR       Norm
# 2217         Low    AllPub    Inside       Mod       IDOTRR       Norm
# 2251         Low    AllPub    Inside       Gtl       IDOTRR       Norm
# 2905         Lvl    AllPub    Inside       Gtl      Mitchel     Artery
#
#      Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# Id
# 1916       Norm     1Fam     1Story            2            4       1910
# 2217       Norm     1Fam     1Story            1            5       1952
# 2251       Norm     1Fam     2.5Unf            5            1       1900
# 2905       Norm     1Fam     1Story            1            3       1951
#
#       YearRemodAdd RoofStyle RoofMatl Exterior1st Exterior2nd MasVnrType  \
# Id
# 1916          1950     Gable  CompShg     Wd Sdng     Wd Sdng       None
# 2217          1952     Gable  CompShg     AsbShng     VinylSd       None
# 2251          1950       Hip  CompShg     Wd Sdng     Wd Sdng       None
# 2905          1951     Gable  CompShg      CBlock     VinylSd       None
#
#       MasVnrArea ExterQual ExterCond Foundation BsmtQual BsmtCond  \
# Id
# 1916         0.0        Fa        Fa     CBlock   NoBsmt   NoBsmt
# 2217         0.0        Fa        Po       Slab   NoBsmt   NoBsmt
# 2251         0.0        TA        TA     BrkTil       TA       TA
# 2905         0.0        TA        Fa     CBlock   NoBsmt   NoBsmt
#
#      BsmtExposure BsmtFinType1  BsmtFinSF1 BsmtFinType2  BsmtFinSF2  \
# Id
# 1916       NoBsmt       NoBsmt         0.0       NoBsmt         0.0
# 2217       NoBsmt       NoBsmt         0.0       NoBsmt         0.0
# 2251           No          Unf         0.0          Unf         0.0
# 2905       NoBsmt       NoBsmt         0.0       NoBsmt         0.0
#
#       BsmtUnfSF  TotalBsmtSF Heating HeatingQC CentralAir Electrical  \
# Id
# 1916        0.0          0.0    GasA        TA          N      FuseA
# 2217        0.0          0.0    Wall        Po          N      FuseA
# 2251      686.0        686.0    GasA        Ex          Y      SBrkr
# 2905        0.0          0.0    GasA        TA          Y      FuseA
#
#       1stFlrSF  2ndFlrSF  LowQualFinSF  GrLivArea  BsmtFullBath  BsmtHalfBath  \
# Id
# 1916       810         0             0        810           0.0           0.0
# 2217       733         0             0        733           0.0           0.0
# 2251      1150       686             0       1836           0.0           0.0
# 2905      1600         0             0       1600           0.0           0.0
#
#       FullBath  HalfBath  BedroomAbvGr  KitchenAbvGr KitchenQual  \
# Id
# 1916         1         0             1             1          TA
# 2217         1         0             2             1          Fa
# 2251         2         0             4             1          TA
# 2905         1         1             3             1          TA
#
#       TotRmsAbvGrd Functional  Fireplaces  FireplaceQu GarageType  \
# Id
# 1916             4       Min1           0  NoFireplace     Detchd
# 2217             4        Typ           0  NoFireplace     Attchd
# 2251             7       Maj1           0  NoFireplace     Detchd
# 2905             6        Mod           0  NoFireplace     Attchd
#
#       GarageYrBlt GarageFinish  GarageCars  GarageArea GarageQual GarageCond  \
# Id
# 1916       1975.0          Unf         1.0       280.0         TA         TA
# 2217       1952.0          Unf         2.0       487.0         Fa         Po
# 2251       1900.0          Unf         1.0       288.0         TA         Fa
# 2905       1951.0          Unf         1.0       270.0         Fa         TA
#
#      PavedDrive  WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  \
# Id
# 1916          N         119           24              0          0
# 2217          N           0            0              0          0
# 2251          N           0            0              0          0
# 2905          N           0            0            135          0
#
#       ScreenPorch  PoolArea  PoolQC    Fence    MiscFeature  MiscVal  MoSold  \
# Id
# 1916            0         0  NoPool  NoFence  NoMiscFeature        0       3
# 2217            0         0  NoPool  NoFence  NoMiscFeature        0       2
# 2251            0         0  NoPool  NoFence  NoMiscFeature        0       1
# 2905            0         0  NoPool  NoFence  NoMiscFeature        0       5
#
#       YrSold SaleType SaleCondition
# Id
# 1916    2009    ConLD        Normal
# 2217    2008       WD       Abnorml
# 2251    2008       WD        Normal
# 2905    2006       WD        Normal

# %%
# Check out the zoning for other properties in the neighborhoods.
combined_df.loc[(combined_df["Neighborhood"] == "IDOTRR","MSZoning")].value_counts()
# Out:
# RM         68
# C (all)    22
# Name: MSZoning, dtype: int64

# %%
# These are all residential properties so the missing zoning should be RM since all other residentials in IDOTRR are RM.
combined_df.loc[((combined_df["Neighborhood"] == "IDOTRR") &
                (combined_df[["MSZoning"]].isnull().any(axis=1))), "MSZoning"] = "RM"
# double check the counts. should be 71 now.
combined_df.loc[(combined_df["Neighborhood"] == "IDOTRR","MSZoning")].value_counts()
# Out:
# RM         71
# C (all)    22
# Name: MSZoning, dtype: int64

# %%
combined_df.loc[(combined_df["Neighborhood"] == "Mitchel","MSZoning")].value_counts()
# Out:
# RL    104
# RM      9
# Name: MSZoning, dtype: int64

# %%
# Most properties in the Mitchel neighborhood are zoned as RL. We can check the property size of the few RM properties to see
# if this matches up with what needs to be imputed, otherwise take RL.
combined_df.loc[(combined_df["Neighborhood"] == "Mitchel") & 
                 (combined_df["MSZoning"] == "RM")]
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street    Alley LotShape  \
# Id
# 82           120       RM         32.0     4500   Pave  NoAlley      Reg
# 421           90       RM         78.0     7060   Pave  NoAlley      Reg
# 484          120       RM         32.0     4500   Pave  NoAlley      Reg
# 776          120       RM         32.0     4500   Pave  NoAlley      Reg
# 1194         120       RM          NaN     4500   Pave  NoAlley      Reg
# 2238          90       RM         97.0     8940   Pave  NoAlley      IR1
# 2240         120       RM         32.0     4500   Pave  NoAlley      Reg
# 2601         120       RM         62.0     6710   Pave  NoAlley      IR1
# 2906          90       RM         78.0     7020   Pave  NoAlley      Reg
#
#      LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# Id
# 82           Lvl    AllPub       FR2       Gtl      Mitchel       Norm
# 421          Lvl    AllPub    Inside       Gtl      Mitchel       Norm
# 484          Lvl    AllPub       FR2       Gtl      Mitchel       Norm
# 776          Lvl    AllPub       FR2       Gtl      Mitchel       Norm
# 1194         Lvl    AllPub       FR2       Gtl      Mitchel       Norm
# 2238         Lvl    AllPub    Corner       Gtl      Mitchel       Norm
# 2240         Lvl    AllPub       FR2       Gtl      Mitchel       Norm
# 2601         Lvl    AllPub       FR3       Gtl      Mitchel       Norm
# 2906         Lvl    AllPub    Inside       Gtl      Mitchel       Norm
#
#      Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# Id
# 82         Norm   TwnhsE     1Story            6            5       1998
# 421        Norm   Duplex     SFoyer            7            5       1997
# 484        Norm    Twnhs     1Story            6            5       1998
# 776        Norm   TwnhsE     1Story            6            5       1998
# 1194       Norm   TwnhsE     1Story            6            5       1999
# 2238       Norm   Duplex     SFoyer            7            5       1997
# 2240       Norm   TwnhsE     1Story            6            5       1997
# 2601       Norm   TwnhsE     SFoyer            6            5       1996
# 2906       Norm   Duplex     SFoyer            7            5       1997
#
#       YearRemodAdd RoofStyle RoofMatl Exterior1st Exterior2nd MasVnrType  \
# Id
# 82            1998       Hip  CompShg     VinylSd     VinylSd    BrkFace
# 421           1998     Gable  CompShg     VinylSd     VinylSd    BrkFace
# 484           1998       Hip  CompShg     VinylSd     VinylSd    BrkFace
# 776           1998       Hip  CompShg     VinylSd     VinylSd    BrkFace
# 1194          1999       Hip  CompShg     VinylSd     VinylSd    BrkFace
# 2238          1998     Gable  CompShg     VinylSd     VinylSd    BrkFace
# 2240          1997       Hip  CompShg     VinylSd     VinylSd    BrkFace
# 2601          1997     Gable  CompShg     VinylSd     VinylSd    BrkFace
# 2906          1997     Gable  CompShg     MetalSd     MetalSd    BrkFace
#
#       MasVnrArea ExterQual ExterCond Foundation BsmtQual BsmtCond  \
# Id
# 82         443.0        TA        Gd      PConc       Ex       Gd
# 421        200.0        TA        Gd      PConc       Gd       Gd
# 484        116.0        TA        TA      PConc       Ex       TA
# 776        320.0        TA        TA      PConc       Ex       TA
# 1194       425.0        TA        TA      PConc       Ex       TA
# 2238       200.0        TA        Gd      PConc       Gd       Gd
# 2240       197.0        TA        TA      PConc       Ex       TA
# 2601       134.0        TA        TA      PConc       Ex       TA
# 2906       200.0        TA        Gd      PConc       Gd       TA
#
#      BsmtExposure BsmtFinType1  BsmtFinSF1 BsmtFinType2  BsmtFinSF2  \
# Id
# 82             No          GLQ      1201.0          Unf         0.0
# 421            Gd          GLQ      1309.0          Unf         0.0
# 484            No          GLQ       897.0          Unf         0.0
# 776            No          GLQ       866.0          Unf         0.0
# 1194           No          GLQ       883.0          Unf         0.0
# 2238           Gd          GLQ      1309.0          Unf         0.0
# 2240           No          GLQ       864.0          Unf         0.0
# 2601           Av          Rec        16.0          GLQ       904.0
# 2906           Gd          GLQ      1243.0          Unf         0.0
#
#       BsmtUnfSF  TotalBsmtSF Heating HeatingQC CentralAir Electrical  \
# Id
# 82         36.0       1237.0    GasA        Ex          Y      SBrkr
# 421        35.0       1344.0    GasA        Ex          Y      SBrkr
# 484       319.0       1216.0    GasA        Ex          Y      SBrkr
# 776       338.0       1204.0    GasA        Ex          Y      SBrkr
# 1194      341.0       1224.0    GasA        Ex          Y      SBrkr
# 2238       35.0       1344.0    GasA        Ex          Y      SBrkr
# 2240      325.0       1189.0    GasA        Ex          Y      SBrkr
# 2601        0.0        920.0    GasA        Ex          Y      SBrkr
# 2906       45.0       1288.0    GasA        Gd          Y      SBrkr
#
#       1stFlrSF  2ndFlrSF  LowQualFinSF  GrLivArea  BsmtFullBath  BsmtHalfBath  \
# Id
# 82        1337         0             0       1337           1.0           0.0
# 421       1344         0             0       1344           2.0           0.0
# 484       1216         0             0       1216           1.0           0.0
# 776       1204         0             0       1204           1.0           0.0
# 1194      1224         0             0       1224           1.0           0.0
# 2238      1344         0             0       1344           2.0           0.0
# 2240      1189         0             0       1189           1.0           0.0
# 2601       936         0             0        936           2.0           0.0
# 2906      1368         0             0       1368           2.0           0.0
#
#       FullBath  HalfBath  BedroomAbvGr  KitchenAbvGr KitchenQual  \
# Id
# 82           2         0             2             1          TA
# 421          2         0             2             2          TA
# 484          2         0             2             1          TA
# 776          2         0             2             1          TA
# 1194         2         0             2             1          TA
# 2238         2         0             2             2          TA
# 2240         2         0             2             1          TA
# 2601         0         1             0             1          TA
# 2906         2         0             2             2          TA
#
#       TotRmsAbvGrd Functional  Fireplaces  FireplaceQu GarageType  \
# Id
# 82               5        Typ           0  NoFireplace     Attchd
# 421              8        Typ           0  NoFireplace     Attchd
# 484              5        Typ           0  NoFireplace     Attchd
# 776              5        Typ           0  NoFireplace     Attchd
# 1194             5        Typ           0  NoFireplace     Attchd
# 2238             8        Typ           0  NoFireplace     Attchd
# 2240             4        Typ           0  NoFireplace     Attchd
# 2601             3        Typ           0  NoFireplace     Attchd
# 2906             8        Typ           0  NoFireplace     Attchd
#
#       GarageYrBlt GarageFinish  GarageCars  GarageArea GarageQual GarageCond  \
# Id
# 82         1998.0          Fin         2.0       405.0         TA         TA
# 421        1997.0          Fin         4.0       784.0         TA         TA
# 484        1998.0          Unf         2.0       402.0         TA         TA
# 776        1998.0          Fin         2.0       412.0         TA         TA
# 1194       1999.0          Fin         2.0       402.0         TA         TA
# 2238       1997.0          Fin         4.0       784.0         TA         TA
# 2240       1997.0          RFn         2.0       392.0         TA         TA
# 2601       1996.0          Fin         2.0       460.0         TA         TA
# 2906       1997.0          Fin         4.0       784.0         TA         TA
#
#      PavedDrive  WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  \
# Id
# 82            Y           0          199              0          0
# 421           Y           0            0              0          0
# 484           Y           0          125              0          0
# 776           Y           0          247              0          0
# 1194          Y           0          304              0          0
# 2238          Y           0            0              0          0
# 2240          Y           0          122              0          0
# 2601          Y           0           40              0          0
# 2906          Y           0           48              0          0
#
#       ScreenPorch  PoolArea  PoolQC    Fence    MiscFeature  MiscVal  MoSold  \
# Id
# 82              0         0  NoPool  NoFence  NoMiscFeature        0       3
# 421             0         0  NoPool  NoFence  NoMiscFeature        0      11
# 484             0         0  NoPool  NoFence  NoMiscFeature        0       5
# 776             0         0  NoPool  NoFence  NoMiscFeature        0       6
# 1194            0         0  NoPool  NoFence  NoMiscFeature        0       6
# 2238            0         0  NoPool  NoFence  NoMiscFeature        0      11
# 2240            0         0  NoPool  NoFence  NoMiscFeature        0       4
# 2601            0         0  NoPool  NoFence  NoMiscFeature        0       6
# 2906            0         0  NoPool  NoFence  NoMiscFeature        0      11
#
#       YrSold SaleType SaleCondition
# Id
# 82      2006       WD        Normal
# 421     2008       WD        Alloca
# 484     2006       WD        Normal
# 776     2009       WD        Normal
# 1194    2009       WD        Normal
# 2238    2008       WD        Alloca
# 2240    2008       WD        Normal
# 2601    2007       WD        Normal
# 2906    2006       WD        Normal

# %%
# All the RM have much lower LotFrontage so using RL for our imputed value seems safe.
combined_df.loc[((combined_df["Neighborhood"] == "Mitchel") &
                (combined_df[["MSZoning"]].isnull().any(axis=1))), "MSZoning"] = "RL"
# check the counts... should be 105 RL now
combined_df.loc[(combined_df["Neighborhood"] == "Mitchel","MSZoning")].value_counts()
# Out:
# RL    105
# RM      9
# Name: MSZoning, dtype: int64

# %%
## MasVnrType, MasVnrArea
# If properties have both of these values missing, presume that the feature doesn't apply. Set Area to 0 and type should be "None".
# There's 1 property that has MasVnrType missing but Area not missing, check this one out first.
combined_df.loc[(combined_df["MasVnrType"].isnull() & combined_df["MasVnrArea"].notnull()),:]
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street    Alley LotShape  \
# Id
# 2611          20       RL        124.0    27697   Pave  NoAlley      Reg
#
#      LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# Id
# 2611         Lvl    AllPub    Inside       Gtl      Mitchel       Norm
#
#      Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# Id
# 2611       Norm     1Fam     1Story            4            3       1961
#
#       YearRemodAdd RoofStyle RoofMatl Exterior1st Exterior2nd MasVnrType  \
# Id
# 2611          1961      Shed  CompShg     Plywood     Plywood        NaN
#
#       MasVnrArea ExterQual ExterCond Foundation BsmtQual BsmtCond  \
# Id
# 2611       198.0        TA        TA     CBlock       TA       TA
#
#      BsmtExposure BsmtFinType1  BsmtFinSF1 BsmtFinType2  BsmtFinSF2  \
# Id
# 2611           No          BLQ       811.0          Unf         0.0
#
#       BsmtUnfSF  TotalBsmtSF Heating HeatingQC CentralAir Electrical  \
# Id
# 2611      585.0       1396.0    GasA        TA          N      SBrkr
#
#       1stFlrSF  2ndFlrSF  LowQualFinSF  GrLivArea  BsmtFullBath  BsmtHalfBath  \
# Id
# 2611      1608         0             0       1608           0.0           0.0
#
#       FullBath  HalfBath  BedroomAbvGr  KitchenAbvGr KitchenQual  \
# Id
# 2611         1         0             3             1          TA
#
#       TotRmsAbvGrd Functional  Fireplaces  FireplaceQu GarageType  \
# Id
# 2611             6        Typ           0  NoFireplace     Attchd
#
#       GarageYrBlt GarageFinish  GarageCars  GarageArea GarageQual GarageCond  \
# Id
# 2611       1961.0          Unf         1.0       444.0         TA         Fa
#
#      PavedDrive  WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  \
# Id
# 2611          Y         152           38              0          0
#
#       ScreenPorch  PoolArea  PoolQC    Fence    MiscFeature  MiscVal  MoSold  \
# Id
# 2611            0         0  NoPool  NoFence  NoMiscFeature        0      11
#
#       YrSold SaleType SaleCondition
# Id
# 2611    2007      COD       Abnorml

# %%
## Since MasVnrArea is non-zero we should impute using similar properties from the neighborhood built around same timeframe.
#combined_df.loc[((combined_df["Neighborhood"] == "Mitchel") & (combined_df["YearBuilt"] == 1961)),:]
combined_df.loc[((combined_df["Neighborhood"] == "Mitchel")& (combined_df["Exterior1st"] == "Plywood")),:]
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street    Alley LotShape  \
# Id
# 202           20       RL         75.0    10125   Pave  NoAlley      Reg
# 455           90       RL         63.0     9297   Pave  NoAlley      Reg
# 780           90       RL         78.0    10530   Pave  NoAlley      Reg
# 784           85       RL          NaN     9101   Pave  NoAlley      IR1
# 941           90       RL         55.0    12640   Pave  NoAlley      IR1
# 985           90       RL         75.0    10125   Pave  NoAlley      Reg
# 1139          20       RL          NaN     9819   Pave  NoAlley      IR1
# 1171          80       RL         76.0     9880   Pave  NoAlley      Reg
# 1606          80       RL         74.0     9620   Pave  NoAlley      Reg
# 1607          90       RL          NaN    12760   Pave  NoAlley      IR1
# 1611          20       RL         85.0    15300   Pave  NoAlley      Reg
# 1918          85       RL         75.0     9750   Pave  NoAlley      Reg
# 1919          85       RL         72.0     9360   Pave  NoAlley      Reg
# 2225          90       RL         76.0    10260   Pave  NoAlley      Reg
# 2246          20       RL          NaN    17979   Pave  NoAlley      IR1
# 2588          80       RL          NaN     8750   Pave  NoAlley      IR1
# 2589          85       RL         82.0     8410   Pave  NoAlley      IR1
# 2606          85       RL         72.0     9129   Pave  NoAlley      Reg
# 2608          20       RL         61.0    33983   Pave  NoAlley      IR1
# 2609          60       RL         68.0     8286   Pave  NoAlley      IR1
# 2611          20       RL        124.0    27697   Pave  NoAlley      Reg
# 2612          20       RL          NaN    11000   Pave  NoAlley      IR2
# 2614          20       RL         62.0    10447   Pave  NoAlley      Reg
# 2897          20       RL         69.0    23580   Pave  NoAlley      IR1
# 2898          90       RL         65.0     8385   Pave  NoAlley      Reg
# 2900          80       RL        140.0    11080   Pave  NoAlley      Reg
# 2908          20       RL         58.0    10172   Pave  NoAlley      IR1
# 2909          90       RL          NaN    11836   Pave  NoAlley      IR1
# 2912          20       RL         80.0    13384   Pave  NoAlley      Reg
#
#      LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# Id
# 202          Lvl    AllPub    Inside       Gtl      Mitchel       Norm
# 455          Lvl    AllPub    Inside       Gtl      Mitchel       Norm
# 780          Lvl    AllPub    Inside       Gtl      Mitchel       Norm
# 784          Lvl    AllPub    Corner       Gtl      Mitchel       Norm
# 941          Lvl    AllPub    Inside       Gtl      Mitchel       Norm
#
1.0           0.0
#
#       FullBath  HalfBath  BedroomAbvGr  KitchenAbvGr KitchenQual  \
# Id
# 202          2         0             3             1          TA
# 455          2         0             4             2          TA
# 780          1         0             2             1          TA
# 784          1         0             1             1          Gd
# 941          2         0             4             2          TA
# 985          2         0             4             2          Gd
# 1139         2         0             2             1          Gd
# 1171         1         0             3             1          TA
# 1606         2         0             3             1          Gd
# 1607         3         0             5             2          TA
# 1611         1         0             2             1          TA
# 1918         1         0             2             1          TA
# 1919         1         1             2             1          TA
# 2225         2         2             4             2          TA
# 2246         1         0             3             1          Gd
# 2588         1         0             3             0          TA
# 2589         1         0             2             1          TA
# 2606         1         0             1             1          Gd
# 2608         1         1             3             1          Gd
# 2609         1         1             3             1          TA
# 2611         1         0             3             1          TA
# 2612         1         1             3             1          TA
# 2614         1         0             3             1          TA
# 2897         2         0             3             1          Fa
# 2898         2         0             4             2          TA
# 2900         2         0             3             1          TA
# 2908         1         0             3             1          TA
# 2909         2         0             4             2          TA
# 2912         1         0             3             1          TA
#
#       TotRmsAbvGrd Functional  Fireplaces  FireplaceQu GarageType  \
# Id
# 202              6        Typ           2           Fa     Detchd
# 455              8        Typ           0  NoFireplace     Detchd
# 780              4        Typ           0  NoFireplace     Attchd
# 784              4        Typ           1           TA     Attchd
# 941              8        Typ           0  NoFireplace     Attchd
# 985              8        Typ           0  NoFireplace     Attchd
# 1139             5        Typ           2           TA     Attchd
# 1171             6        Typ           1           Po     Attchd
# 1606             6        Typ           1           Fa     Attchd
# 1607             9        Typ           0  NoFireplace     2Types
# 1611             7        Typ           1           TA     Attchd
# 1918             5        Typ           1           TA     Attchd
# 1919             5        Typ           2           Fa     Attchd
# 2225             8        Typ           0  NoFireplace     Attchd
# 2246             6        Typ           0  NoFireplace     Attchd
# 2588             4        Typ           0  NoFireplace     Attchd
# 2589             5        Typ           1           Po     Attchd
# 2606             4        Typ           1           Fa     Attchd
# 2608             6        Mod           2           TA     Attchd
# 2609             6        Typ           1           Gd     Attchd
# 2611             6        Typ           0  NoFireplace     Attchd
# 2612             6        Typ           0  NoFireplace     Attchd
# 2614             5        Typ           0  NoFireplace     Attchd
# 2897             6        Typ           1           TA     Attchd
# 2898            10        Typ           0  NoFireplace     2Types
# 2900             6        Typ           0  NoFireplace     Attchd
# 2908             5        Typ           0  NoFireplace     Attchd
# 2909             8        Typ           0  NoFireplace     2Types
# 2912             8        Typ           1           TA     Attchd
#
#       GarageYrBlt GarageFinish  GarageCars  GarageArea GarageQual GarageCond  \
# Id
# 202        1980.0          Unf         2.0       473.0         TA         TA
# 455        1976.0          Unf         2.0       560.0         TA         TA
# 780        1977.0          Unf         2.0       504.0         TA         TA
# 784        1978.0          Fin         2.0       602.0         TA         TA
# 941        1976.0          Unf         2.0       574.0         TA         TA
# 985        1977.0          Unf         2.0       539.0         TA         TA
# 1139       1977.0          RFn         2.0       714.0         TA         TA
# 1171       1977.0          Fin         1.0       358.0         TA         TA
# 1606       1977.0          Unf         2.0       473.0         TA         TA
# 1607       1976.0          Unf         2.0       776.0         TA         TA
# 1611       1965.0          Unf         2.0       528.0         TA         TA
# 1918       1977.0          Unf         1.0       351.0         TA         TA
# 1919       1977.0          RFn         2.0       541.0         TA         TA
# 2225       1976.0          Unf         2.0       484.0         TA         TA
# 2246       1968.0          Unf         1.0       257.0         TA         TA
# 2588       1975.0          Unf         1.0       360.0         TA         TA
# 2589       1974.0          Unf         2.0       528.0         TA         TA
# 2606       1977.0          Fin         2.0       678.0         TA         TA
# 2608       1977.0          RFn         2.0       672.0         TA         TA
# 2609       1977.0          Fin         2.0       531.0         TA         TA
# 2611       1961.0          Unf         1.0       444.0         TA         Fa
# 2612       1976.0          Unf         2.0       502.0         TA         TA
# 2614       1984.0          RFn         1.0       288.0         TA         TA
# 2897       1979.0          Fin         2.0       576.0         TA         TA
# 2898       1978.0          Unf         2.0       616.0         TA         TA
# 2900       1975.0          Unf         2.0       528.0         TA         TA
# 2908       1968.0          RFn         1.0       288.0         TA         TA
# 2909       1970.0          Unf         3.0       928.0         TA         TA
# 2912       1969.0          RFn         1.0       336.0         TA         TA
#
#      PavedDrive  WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  \
# Id
# 202           Y         238           83              0          0
# 455           Y           0            0              0          0
# 780           Y           0            0              0          0
# 784           Y         303           30              0          0
# 941           Y          40            0              0          0
# 985           Y           0            0              0          0
# 1139          Y         264           32              0          0
# 1171          Y         203            0              0          0
# 1606          Y         375           26              0          0
# 1607          Y           0            0              0          0
# 1611          Y           0            0              0          0
# 1918          Y         319            0              0          0
# 1919          Y         302           39              0          0
# 2225          Y           0            0              0          0
# 2246          Y          81            0              0          0
# 2588          Y         192           84              0          0
# 2589          Y         193            0              0          0
# 2606          Y         201           66              0          0
# 2608          P         690           90              0          0
# 2609          Y           0          136              0          0
# 2611          Y         152           38              0          0
# 2612          Y           0           44              0          0
# 2614          Y         140            0              0          0
# 2897          Y         136           28              0          0
# 2898          Y           0            0              0          0
# 2900          Y           0            0              0          0
# 2908          Y           0          120              0          0
# 2909          Y           0            0              0          0
# 2912          Y         160            0              0          0
#
#       ScreenPorch  PoolArea  PoolQC    Fence    MiscFeature  MiscVal  MoSold  \
# Id
# 202             0         0  NoPool    MnPrv  NoMiscFeature        0       2
# 455             0         0  NoPool  NoFence  NoMiscFeature        0       7
# 780             0         0  NoPool  NoFence  NoMiscFeature        0       5
# 784             0         0  NoPool  NoFence  NoMiscFeature        0       7
# 941             0         0  NoPool  NoFence  NoMiscFeature        0       7
# 985             0         0  NoPool  NoFence  NoMiscFeature        0       8
# 1139            0         0  NoPool  NoFence  NoMiscFeature        0       5
# 1171            0       576      Gd    GdPrv  NoMiscFeature        0       7
# 1606            0         0  NoPool    GdPrv           Shed       80       5
# 1607            0         0  NoPool  NoFence  NoMiscFeature        0       3
# 1611            0         0  NoPool  NoFence  NoMiscFeature        0       6
# 1918            0         0  NoPool    MnPrv  NoMiscFeature        0       4
# 1919          120         0  NoPool     GdWo  NoMiscFeature        0      11
# 2225            0         0  NoPool  NoFence  NoMiscFeature        0      11
# 2246            0         0  NoPool     GdWo           Shed      500       2
# 2588            0         0  NoPool  NoFence  NoMiscFeature        0       3
# 2589            0         0  NoPool  NoFence  NoMiscFeature        0       4
# 2606            0         0  NoPool    MnPrv  NoMiscFeature        0       7
# 2608            0         0  NoPool    GdPrv  NoMiscFeature        0       5
# 2609          240         0  NoPool    GdPrv  NoMiscFeature        0       6
# 2611            0         0  NoPool  NoFence  NoMiscFeature        0      11
# 2612           88         0  NoPool    MnPrv  NoMiscFeature        0       6
# 2614            0         0  NoPool  NoFence  NoMiscFeature        0      12
# 2897            0         0  NoPool  NoFence  NoMiscFeature        0       9
# 2898            0         0  NoPool  NoFence  NoMiscFeature        0      10
# 2900            0         0  NoPool  NoFence  NoMiscFeature        0       5
# 2908            0         0  NoPool  NoFence  NoMiscFeature        0      10
# 2909            0         0  NoPool  NoFence  NoMiscFeature        0       3
# 2912            0         0  NoPool  NoFence  NoMiscFeature        0       5
#
#       YrSold SaleType SaleCondition
# Id
# 202     2008       WD        Normal
# 455     2006       WD        Family
# 780     2006       WD        Normal
# 784     2009       WD        Normal
# 941     2006       WD        Normal
# 985     2009      COD        Normal
# 1139    2009       WD        Normal
# 1171    2008       WD        Normal
# 1606    2010       WD        Normal
# 1607    2010    ConLD        Normal
# 1611    2010       WD        Normal
# 1918    2009       WD        Normal
# 1919    2009       WD        Normal
# 2225    2008       WD       Abnorml
# 2246    2008       WD        Normal
# 2588    2007       WD        Normal
# 2589    2007       WD        Normal
# 2606    2007       WD        Normal
# 2608    2007       WD        Normal
# 2609    2007       WD        Normal
# 2611    2007      COD       Abnorml
# 2612    2007       WD        Normal
# 2614    2007       WD        Normal
# 2897    2006       WD        Normal
# 2898    2006       WD        Normal
# 2900    2006       WD        Normal
# 2908    2006       WD        Normal
# 2909    2006       WD        Normal
# 2912    2006       WD        Normal

# %% [markdown]
# By inspecting similar properties in the neighborhood with similar exterior building material, we see most common masonry veneer type is "BrkFace", though there's 1 instance of "Stone". Imputing with "BrkFace" is sensible.

# %%
combined_df.loc[(combined_df["MasVnrType"].isnull() & combined_df["MasVnrArea"].notnull()),"MasVnrType"] = "BrkFace"

# %%
## Now fix remaining missing values
combined_df["MasVnrType"] = combined_df["MasVnrType"].fillna("None")
combined_df["MasVnrArea"] = combined_df["MasVnrArea"].fillna(0)

# %%
combined_df.loc[combined_df["Electrical"].isnull(),:]
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street    Alley LotShape  \
# Id
# 1380          80       RL         73.0     9735   Pave  NoAlley      Reg
#
#      LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# Id
# 1380         Lvl    AllPub    Inside       Gtl       Timber       Norm
#
#      Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# Id
# 1380       Norm     1Fam       SLvl            5            5       2006
#
#       YearRemodAdd RoofStyle RoofMatl Exterior1st Exterior2nd MasVnrType  \
# Id
# 1380          2007     Gable  CompShg     VinylSd     VinylSd       None
#
#       MasVnrArea ExterQual ExterCond Foundation BsmtQual BsmtCond  \
# Id
# 1380         0.0        TA        TA      PConc       Gd       TA
#
#      BsmtExposure BsmtFinType1  BsmtFinSF1 BsmtFinType2  BsmtFinSF2  \
# Id
# 1380           No          Unf         0.0          Unf         0.0
#
#       BsmtUnfSF  TotalBsmtSF Heating HeatingQC CentralAir Electrical  \
# Id
# 1380      384.0        384.0    GasA        Gd          Y        NaN
#
#       1stFlrSF  2ndFlrSF  LowQualFinSF  GrLivArea  BsmtFullBath  BsmtHalfBath  \
# Id
# 1380       754       640             0       1394           0.0           0.0
#
#       FullBath  HalfBath  BedroomAbvGr  KitchenAbvGr KitchenQual  \
# Id
# 1380         2         1             3             1          Gd
#
#       TotRmsAbvGrd Functional  Fireplaces  FireplaceQu GarageType  \
# Id
# 1380             7        Typ           0  NoFireplace    BuiltIn
#
#       GarageYrBlt GarageFinish  GarageCars  GarageArea GarageQual GarageCond  \
# Id
# 1380       2007.0          Fin         2.0       400.0         TA         TA
#
#      PavedDrive  WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  \
# Id
# 1380          Y         100            0              0          0
#
#       ScreenPorch  PoolArea  PoolQC    Fence    MiscFeature  MiscVal  MoSold  \
# Id
# 1380            0         0  NoPool  NoFence  NoMiscFeature        0       5
#
#       YrSold SaleType SaleCondition
# Id
# 1380    2008       WD        Normal

# %% [markdown]
# This is a pretty new house built in 2006 and it's unlikely that it's actually not wired for electrical service. We would probably want to impute the value for Electrical feature from similar houses built in this neighborhood around the same timeframe.

# %%
combined_df.loc[(combined_df["YearBuilt"] == 2006) & (combined_df["Neighborhood"] == "Timber"),:]
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street    Alley LotShape  \
# Id
# 541           20       RL         85.0    14601   Pave  NoAlley      Reg
# 867           20       RL         67.0    10656   Pave  NoAlley      IR1
# 1240          20       RL         64.0     9037   Pave  NoAlley      IR1
# 1348          20       RL         93.0    15306   Pave  NoAlley      IR1
# 1380          80       RL         73.0     9735   Pave  NoAlley      Reg
# 1610          60       RL         73.0     9802   Pave  NoAlley      Reg
# 2228          20       RL         74.0    11563   Pave  NoAlley      IR1
# 2230          80       RL         73.0     9802   Pave  NoAlley      Reg
# 2592          20       RL         67.0     8368   Pave  NoAlley      IR1
# 2593          20       RL         68.0     8298   Pave  NoAlley      IR1
# 2599          20       RL         85.0    12633   Pave  NoAlley      IR1
#
#      LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# Id
# 541          Lvl    AllPub    Inside       Gtl       Timber       Norm
# 867          HLS    AllPub    Inside       Gtl       Timber       Norm
# 1240         HLS    AllPub    Inside       Gtl       Timber       Norm
# 1348         HLS    AllPub    Corner       Gtl       Timber       Norm
# 1380         Lvl    AllPub    Inside       Gtl       Timber       Norm
# 1610         Lvl    AllPub    Inside       Gtl       Timber       Norm
# 2228         HLS    AllPub    Inside       Gtl       Timber       Norm
# 2230         Lvl    AllPub    Inside       Gtl       Timber       Norm
# 2592         HLS    AllPub    Inside       Gtl       Timber       Norm
# 2593         HLS    AllPub    Inside       Gtl       Timber       Norm
# 2599         HLS    AllPub    Inside       Gtl       Timber       PosA
#
#      Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# Id
# 541        Norm     1Fam     1Story            9            5       2006
# 867        Norm     1Fam     1Story            8            5       2006
# 1240       Norm     1Fam     1Story            8            5       2006
# 1348       Norm     1Fam     1Story            8            5       2006
# 1380       Norm     1Fam       SLvl            5            5       2006
# 1610       Norm     1Fam     2Story            5            5       2006
# 2228       Norm     1Fam     1Story            8            5       2006
# 2230       Norm     1Fam       SLvl            5            5       2006
# 2592       Norm     1Fam     1Story            7            5       2006
# 2593       Norm     1Fam     1Story            8            5       2006
# 2599       PosA     1Fam     1Story           10            5       2006
#
#       YearRemodAdd RoofStyle RoofMatl Exterior1st Exterior2nd MasVnrType  \
# Id
# 541           2006       Hip  CompShg     VinylSd     VinylSd    BrkFace
# 867           2007     Gable  CompShg     VinylSd     VinylSd      Stone
# 1240          2006       Hip  CompShg     VinylSd     VinylSd    BrkFace
# 1348          2007     Gable  CompShg     VinylSd     VinylSd      Stone
# 1380          2007     Gable  CompShg     VinylSd     VinylSd       None
# 1610          2007     Gable  CompShg     VinylSd     VinylSd       None
# 2228          2007       Hip  CompShg     VinylSd     VinylSd      Stone
# 2230          2007     Gable  CompShg     VinylSd     VinylSd       None
# 2592          2007     Gable  CompShg     VinylSd     VinylSd       None
# 2593          2007       Hip  CompShg     VinylSd     VinylSd       None
# 2599          2007       Hip  CompShg     MetalSd     MetalSd    BrkFace
#
#       MasVnrArea ExterQual ExterCond Foundation BsmtQual BsmtCond  \
# Id
# 541        584.0        Ex        TA      PConc       Ex       TA
# 867        274.0        Gd        TA      PConc       Gd       TA
# 1240        32.0        Gd        TA      PConc       Gd       TA
# 1348       100.0        Gd        TA      PConc       Ex       TA
# 1380         0.0        TA        TA      PConc       Gd       TA
# 1610         0.0        TA        TA      PConc       Gd       TA
# 2228       258.0        Gd        TA      PConc       Ex       TA
# 2230         0.0        TA        TA      PConc       Gd       TA
# 2592         0.0        Gd        TA      PConc       Gd       TA
# 2593         0.0        Gd        TA      PConc       Gd       TA
# 2599       242.0        Ex        TA      PConc       Ex       TA
#
#      BsmtExposure BsmtFinType1  BsmtFinSF1 BsmtFinType2  BsmtFinSF2  \
# Id
# 541            Av          GLQ      1260.0          Unf         0.0
# 867            Av          Unf         0.0          Unf         0.0
# 1240           Av          GLQ       428.0          Unf         0.0
# 1348           Gd          GLQ        80.0          Unf         0.0
# 1380           No          Unf         0.0          Unf         0.0
# 1610           No          Unf         0.0          Unf         0.0
# 2228           Gd          GLQ      1036.0          Unf         0.0
# 2230           No          Unf         0.0          Unf         0.0
# 2592           No          Unf         0.0          Unf         0.0
# 2593           Av          GLQ       583.0          Unf         0.0
# 2599           Gd          Unf         0.0          Unf         0.0
#
#       BsmtUnfSF  TotalBsmtSF Heating HeatingQC CentralAir Electrical  \
# Id
# 541       578.0       1838.0    GasA        Ex          Y      SBrkr
# 867      1638.0       1638.0    GasA        Ex          Y      SBrkr
# 1240     1048.0       1476.0    GasA        Ex          Y      SBrkr
# 1348     1652.0       1732.0    GasA        Ex          Y      SBrkr
# 1380      384.0        384.0    GasA        Gd          Y        NaN
# 1610      384.0        384.0    GasA        Gd          Y      SBrkr
# 2228      482.0       1518.0    GasA        Ex          Y      SBrkr
# 2230      352.0        352.0    GasA        Gd          Y      SBrkr
# 2592     1689.0       1689.0    GasA        Ex          Y      SBrkr
# 2593      963.0       1546.0    GasA        Ex          Y      SBrkr
# 2599     1824.0       1824.0    GasA        Ex          Y      SBrkr
#
#       1stFlrSF  2ndFlrSF  LowQualFinSF  GrLivArea  BsmtFullBath  BsmtHalfBath  \
# Id
#
0         0  NoPool  NoFence  NoMiscFeature        0       4
# 2593            0         0  NoPool  NoFence  NoMiscFeature        0       9
# 2599          108         0  NoPool  NoFence  NoMiscFeature        0       9
#
#       YrSold SaleType SaleCondition
# Id
# 541     2009       WD        Normal
# 867     2007      New       Partial
# 1240    2007       WD        Normal
# 1348    2007      New       Partial
# 1380    2008       WD        Normal
# 1610    2010       WD        Normal
# 2228    2008       WD        Normal
# 2230    2008       WD        Normal
# 2592    2007      New       Partial
# 2593    2007      New       Partial
# 2599    2007      New       Partial

# %%
# All other houses in this neighborhood built in same year had "SBrkr" electrical type. So replace missing value with SBrkr.
combined_df["Electrical"] = combined_df["Electrical"].fillna("SBrkr")

# %%
# GarageYrBlt
print(combined_df.loc[combined_df["GarageYrBlt"].isnull(),"GarageType"].value_counts())
print(combined_df.loc[combined_df["GarageYrBlt"].isnull(),"GarageFinish"].value_counts())
# Out:
# NoGarage    158
# Detchd        1
# Name: GarageType, dtype: int64
# NoGarage    159
# Name: GarageFinish, dtype: int64

# %%
# Fill in missing GarageYrBlt with YearBuilt field. 
# Fill with 0 may be another option but I feel that may throw a model off. 
# Further this is missing only when a property doesn't have a garage (feature doesn't apply) 
# and we have a categorical feature that will indicate when there's no garage.
combined_df["GarageYrBlt"].fillna(combined_df["YearBuilt"], inplace = True)
# Fix the property with "detchd" garagetype, that doesn't have a garage
combined_df.loc[((combined_df["GarageType"] == "Detchd") & (combined_df["GarageFinish"] == "NoGarage")),"GarageType"] = "NoGarage"
# Check that the fill is correct...
#train_data.loc[train_data["GarageType"] == "NoGarage",["GarageYrBlt","YearBuilt"]]

# %%
# LotFrontage: 
# This one's a bit trickier. We can group by other lot features and fill in with the mean of those
combined_df.loc[combined_df["LotFrontage"].isnull(),:]
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street    Alley LotShape  \
# Id
# 8             60       RL          NaN    10382   Pave  NoAlley      IR1
# 13            20       RL          NaN    12968   Pave  NoAlley      IR2
# 15            20       RL          NaN    10920   Pave  NoAlley      IR1
# 17            20       RL          NaN    11241   Pave  NoAlley      IR1
# 25            20       RL          NaN     8246   Pave  NoAlley      IR1
# 32            20       RL          NaN     8544   Pave  NoAlley      IR1
# 43            85       RL          NaN     9180   Pave  NoAlley      IR1
# 44            20       RL          NaN     9200   Pave  NoAlley      IR1
# 51            60       RL          NaN    13869   Pave  NoAlley      IR2
# 65            60       RL          NaN     9375   Pave  NoAlley      Reg
# 67            20       RL          NaN    19900   Pave  NoAlley      Reg
# 77            20       RL          NaN     8475   Pave  NoAlley      IR1
# 85            80       RL          NaN     8530   Pave  NoAlley      IR1
# 96            60       RL          NaN     9765   Pave  NoAlley      IR2
# 101           20       RL          NaN    10603   Pave  NoAlley      IR1
# 105           50       RM          NaN     7758   Pave  NoAlley      Reg
# 112           80       RL          NaN     7750   Pave  NoAlley      IR1
# 114           20       RL          NaN    21000   Pave  NoAlley      Reg
# 117           20       RL          NaN    11616   Pave  NoAlley      Reg
# 121           80       RL          NaN    21453   Pave  NoAlley      IR1
# 127          120       RL          NaN     4928   Pave  NoAlley      IR1
# 132           60       RL          NaN    12224   Pave  NoAlley      IR1
# 134           20       RL          NaN     6853   Pave  NoAlley      IR1
# 137           20       RL          NaN    10355   Pave  NoAlley      IR1
# 148           60       RL          NaN     9505   Pave  NoAlley      IR1
# 150           50       RM          NaN     6240   Pave  NoAlley      Reg
# 153           60       RL          NaN    14803   Pave  NoAlley      IR1
# 154           20       RL          NaN    13500   Pave  NoAlley      Reg
# 161           20       RL          NaN    11120   Pave  NoAlley      IR1
# 167           20       RL          NaN    10708   Pave  NoAlley      IR1
# ...          ...      ...          ...      ...    ...      ...      ...
# 2685          60       RL          NaN    12585   Pave  NoAlley      IR1
# 2701          60       RL          NaN     9019   Pave  NoAlley      IR1
# 2704          20       RL          NaN     9240   Pave  NoAlley      IR1
# 2705          20       RL          NaN     9308   Pave  NoAlley      IR1
# 2707          20       RL          NaN     8638   Pave  NoAlley      IR1
# 2708          20       RL          NaN    13052   Pave  NoAlley      IR1
# 2709          20       RL          NaN     8020   Pave  NoAlley      IR1
# 2710          20       RL          NaN     8789   Pave  NoAlley      IR1
# 2715         160       FV          NaN     2998   Pave  NoAlley      Reg
# 2716         160       FV          NaN     4447   Pave  NoAlley      IR1
# 2725          20       RL          NaN     9759   Pave  NoAlley      IR1
# 2728          20       RL          NaN    10368   Pave  NoAlley      IR1
# 2738          90       RL          NaN     8917   Pave  NoAlley      IR1
# 2739          80       RL          NaN    12700   Pave  NoAlley      IR1
# 2742          20       RL          NaN     9610   Pave  NoAlley      IR1
# 2765          60       RL          NaN    18275   Pave  NoAlley      IR1
# 2808          20       RL          NaN    11327   Pave  NoAlley      IR1
# 2811          20       RL          NaN     9535   Pave  NoAlley      IR1
# 2812          80       RL          NaN     7176   Pave  NoAlley      IR1
# 2813          90       RL          NaN     9662   Pave  NoAlley      IR1
# 2815          30       RL          NaN    17529   Pave  NoAlley      Reg
# 2816          20       RL          NaN    20355   Pave  NoAlley      Reg
# 2819         150       RL          NaN     1700   Pave  NoAlley      Reg
# 2840          20       RL          NaN     8685   Pave  NoAlley      IR1
# 2846          60       RL          NaN     9930   Pave  NoAlley      IR1
# 2848          20       RL          NaN    11088   Pave  NoAlley      Reg
# 2851          60       RL          NaN    21533   Pave  NoAlley      IR2
# 2901          20       RL          NaN    50102   Pave  NoAlley      IR1
# 2902          20       RL          NaN     8098   Pave  NoAlley      IR1
# 2909          90       RL          NaN    11836   Pave  NoAlley      IR1
#
#      LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# Id
# 8            Lvl    AllPub    Corner       Gtl       NWAmes       PosN
# 13           Lvl    AllPub    Inside       Gtl       Sawyer       Norm
# 15           Lvl    AllPub    Corner       Gtl        NAmes       Norm
# 17           Lvl    AllPub   CulDSac       Gtl        NAmes       Norm
# 25           Lvl    AllPub    Inside       Gtl       Sawyer       Norm
# 32           Lvl    AllPub   CulDSac       Gtl       Sawyer       Norm
# 43           Lvl    AllPub   CulDSac       Gtl      SawyerW       Norm
# 44           Lvl    AllPub   CulDSac       Gtl      CollgCr       Norm
# 51           Lvl    AllPub    Corner       Gtl      Gilbert       Norm
# 65           Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 67           Lvl    AllPub    Inside       Gtl        NAmes       PosA
# 77           Lvl    AllPub    Inside       Gtl        NAmes       Norm
# 85           Lvl    AllPub    Inside       Gtl      Gilbert       Norm
# 96           Lvl    AllPub    Corner       Gtl      Gilbert       Norm
# 101          Lvl    AllPub    Inside       Gtl       NWAmes       Norm
# 105          Lvl    AllPub    Corner       Gtl       IDOTRR       Norm
# 112          Lvl    AllPub    Inside       Gtl      Gilbert       Norm
# 114          Bnk    AllPub    Corner       Gtl      Crawfor       Norm
# 117          Lvl    AllPub    Inside       Gtl       Sawyer       Norm
# 121          Low    AllPub   CulDSac       Sev      ClearCr       Norm
# 127          Lvl    AllPub    Inside       Gtl      NPkVill       Norm
# 132          Lvl    AllPub    Corner       Gtl      Gilbert       Norm
# 134          Lvl    AllPub    Inside       Gtl       Timber       Norm
# 137          Lvl    AllPub    Corner       Gtl        NAmes       Norm
# 148          Lvl    AllPub   CulDSac       Gtl      Gilbert       Norm
# 150          Lvl    AllPub    Inside       Gtl      BrkSide       Norm
# 153          Lvl    AllPub   CulDSac       Gtl       NWAmes       Norm
# 154          Lvl    AllPub    Inside       Gtl      ClearCr       Norm
# 161          Lvl    AllPub   CulDSac       Gtl      Veenker       Norm
# 167          Lvl    AllPub    Inside       Gtl      ClearCr       Norm
# ...          ...       ...       ...       ...          ...        ...
# 2685         Lvl    AllPub    Inside       Gtl      NoRidge       Norm
# 2701         Lvl    AllPub    Inside       Gtl      SawyerW       RRAe
# 2704         Lvl    AllPub    Inside       Gtl       Sawyer       Norm
# 2705         Lvl    AllPub   CulDSac       Gtl       Sawyer       RRNe
# 2707         Lvl    AllPub    Inside       Gtl       Sawyer       RRAe
#
0          Unf         0.0
#
#       BsmtUnfSF  TotalBsmtSF Heating HeatingQC CentralAir Electrical  \
# Id
# 8         216.0       1107.0    GasA        Ex          Y      SBrkr
# 13        175.0        912.0    GasA        TA          Y      SBrkr
# 15        520.0       1253.0    GasA        TA          Y      SBrkr
# 17        426.0       1004.0    GasA        Ex          Y      SBrkr
# 25        204.0       1060.0    GasA        Ex          Y      SBrkr
# 32       1228.0       1228.0    GasA        Gd          Y      SBrkr
# 43          0.0        840.0    GasA        Gd          Y      SBrkr
# 44        167.0        938.0    GasA        TA          Y      SBrkr
# 51        612.0        794.0    GasA        Gd          Y      SBrkr
# 65        318.0       1057.0    GasA        Ex          Y      SBrkr
# 67       1035.0       1947.0    GasA        TA          Y      SBrkr
# 77        724.0        952.0    GasA        Ex          Y      FuseA
# 85        384.0        384.0    GasA        Gd          Y      SBrkr
# 96        370.0        680.0    GasA        Gd          Y      SBrkr
# 101       410.0       1610.0    GasA        Gd          Y      SBrkr
# 105       816.0       1040.0    GasA        Ex          Y      FuseF
# 112       134.0        384.0    GasA        Ex          Y      SBrkr
# 114       905.0       1809.0    GasA        TA          Y      SBrkr
# 117       252.0       1092.0    GasA        TA          Y      SBrkr
# 121         0.0        938.0    GasA        Ex          Y      SBrkr
# 127       958.0       1078.0    GasA        TA          Y      SBrkr
# 132       297.0        992.0    GasA        Ex          Y      SBrkr
# 134       262.0       1267.0    GasA        Ex          Y      SBrkr
# 137       519.0       1214.0    GasA        TA          Y      SBrkr
# 148       884.0        884.0    GasA        Ex          Y      SBrkr
# 150       896.0        896.0    GasA        Gd          Y      FuseA
# 153       409.0        825.0    GasA        Gd          Y      SBrkr
# 154        93.0       1602.0    GasA        Gd          Y      SBrkr
# 161       572.0       1232.0    GasA        TA          Y      SBrkr
# 167       470.0       1617.0    GasA        Ex          Y      FuseA
# ...         ...          ...     ...       ...        ...        ...
# 2685        0.0       1286.0    GasA        Ex          Y      SBrkr
# 2701      362.0        636.0    GasA        Ex          Y      SBrkr
# 2704      252.0        864.0    GasA        Gd          Y      SBrkr
# 2705      430.0        984.0    GasA        TA          Y      SBrkr
# 2707      744.0        925.0    GasA        Gd          Y      SBrkr
# 2708      312.0       1024.0    GasA        TA          Y      SBrkr
# 2709      268.0        912.0    GasA        TA          N      SBrkr
# 2710      253.0        912.0    GasA        TA          Y      SBrkr
# 2715      403.0        756.0    GasA        Ex          Y      SBrkr
# 2716      530.0        530.0    GasA        Ex          Y      SBrkr
# 2725      252.0       1051.0    GasA        TA          Y      SBrkr
# 2728        0.0       1008.0    GasA        Ex          Y      SBrkr
# 2738     1584.0       1584.0    GasA        TA          Y      SBrkr
# 2739      307.0       1246.0    GasA        TA          Y      SBrkr
# 2742      918.0       1121.0    GasA        Ex          Y      FuseA
# 2765      802.0       1438.0    GasA        TA          Y      SBrkr
# 2808      285.0       1064.0    GasA        TA          Y      SBrkr
# 2811        0.0       1176.0    GasA        TA          Y      SBrkr
# 2812      166.0        960.0    GasA        Fa          Y      SBrkr
# 2813     1967.0       1967.0    GasA        TA          Y      SBrkr
0.0           0.0
#
#       FullBath  HalfBath  BedroomAbvGr  KitchenAbvGr KitchenQual  \
# Id
# 8            2         1             3             1          TA
# 13           1         0             2             1          TA
# 15           1         1             2             1          TA
# 17           1         0             2             1          TA
# 25           1         0             3             1          Gd
# 32           1         1             3             1          Gd
# 43           1         0             2             1          Gd
# 44           1         0             3             1          TA
# 51           2         0             3             1          TA
# 65           2         1             3             1          Gd
# 67           2         0             3             1          TA
# 77           1         0             2             1          TA
# 85           2         1             3             1          TA
# 96           2         1             3             1          TA
# 101          2         0             3             1          Gd
# 105          1         1             4             1          TA
# 112          2         1             3             1          TA
# 114          2         0             3             1          Gd
# 117          1         0             3             1          TA
# 121          1         0             1             1          TA
# 127          2         0             2             1          TA
# 132          2         1             3             1          Gd
# 134          2         0             2             1          Gd
# 137          2         0             3             1          TA
# 148          2         1             3             1          Gd
# 150          1         0             3             1          TA
# 153          2         1             4             1          TA
# 154          1         0             1             1          TA
# 161          2         0             3             1          TA
# 167          1         0             2             1          TA
# ...        ...       ...           ...           ...         ...
# 2685         2         1             3             1          Gd
# 2701         2         1             3             1          Gd
# 2704         1         0             2             1          TA
# 2705         1         0             3             1          TA
# 2707         1         0             2             1          TA
# 2708         1         1             3             1          TA
# 2709         1         0             3             1          TA
# 2710         1         0             3             1          TA
# 2715         2         1             2             1          Gd
# 2716         2         1             2             1          Gd
# 2725         1         0             3             1          TA
# 2728         1         1             3             1          TA
# 2738         2         0             4             2          TA
# 2739         1         0             3             1          TA
# 2742         1         1             3             1          TA
# 2765         3         0             3             1          TA
# 2808         1         0             3             1          TA
# 2811         1         1             3             1          TA
# 2812         1         0             3             1          TA
# 2813         2         0             6             2          TA
# 2815         1         0             2             1          Fa
# 2816         1         0             2             1          TA
# 2819         2         1             2             1          Gd
# 2840         2         0             3             1          TA
# 2846         2         1             3             1          Gd
# 2848         1         1             1             1          Gd
# 2851         2         1             4             1          Gd
# 2901         1         0             2             1          TA
# 2902         2         0             2             1          Gd
# 2909         2         0             4             2          TA
#
#       TotRmsAbvGrd Functional  Fireplaces  FireplaceQu GarageType  \
# Id
# 8                7        Typ           2           TA     Attchd
# 13               4        Typ           0  NoFireplace     Detchd
# 15               5        Typ           1           Fa     Attchd
# 17               5        Typ           1           TA     Attchd
# 25               6        Typ           1           TA     Attchd
# 32               6        Typ           0  NoFireplace     Attchd
# 43               5        Typ           0  NoFireplace     Attchd
# 44               5        Typ           0  NoFireplace     Detchd
# 51               6        Typ           0  NoFireplace     Attchd
# 65               8        Typ           0  NoFireplace     Attchd
# 67               7       Min1           1           Gd     Attchd
# 77               4        Typ           0  NoFireplace     Detchd
# 85               7        Typ           1           TA    BuiltIn
# 96               6        Typ           1           TA    BuiltIn
# 101              6        Typ           2           TA     Attchd
# 105              7        Typ           2           TA     Detchd
# 112              7        Typ           1           TA    BuiltIn
# 114              7        Typ           2           Gd    Basment
# 117              6        Typ           1           Po     Attchd
# 121              4        Typ           2           TA     Attchd
# 127              5        Typ           1           TA     Attchd
# 132              7        Typ           1           TA    BuiltIn
# 134              6        Typ           0  NoFireplace     Attchd
# 137              5        Typ           1           Fa     Attchd
# 148              8        Typ           1           Gd    BuiltIn
# 150              7        Typ           0  NoFireplace     Detchd
# 153              8        Typ           1           Gd     Attchd
# 154              4        Typ           1           Gd     Attchd
# 161              6        Typ           0  NoFireplace     Attchd
# 167              7        Typ           3           Gd     Attchd
# ...            ...        ...         ...          ...        ...
# 2685             8        Typ           1           TA     Attchd
# 2701             6        Typ           0  NoFireplace     Attchd
# 2704             6       Min1           1           TA     Detchd
# 2705             5        Typ           0  NoFireplace     Attchd
# 2707             5        Typ           0  NoFireplace     Detchd
# 2708             5        Typ           0  NoFireplace     Attchd
# 2709             6        Typ           0  NoFireplace   NoGarage
# 2710             6        Typ           1           Po     Attchd
# 2715             4        Typ           0  NoFireplace     Detchd
# 2716             4        Typ           0  NoFireplace     Attchd
# 2725             6        Typ           0  NoFireplace     Attchd
# 2728             7        Typ           1           Gd     Attchd
# 2738             8        Typ           0  NoFireplace     Detchd
# 2739             6        Typ           2           Gd     Attchd
# 2742             7        Typ           1           TA     Attchd
# 2765             9        Typ           2           Gd     Attchd
# 2808             6        Typ           1           TA     Attchd
# 2811             7        Typ           1           TA     Attchd
# 2812             6        Typ           1           Fa     Detchd
# 2813            10        Typ           0  NoFireplace     Attchd
# 2815             5        Mod           1           Gd     Detchd
# 2816             6        Typ           2           Gd     Attchd
# 2819             7        Typ           0  NoFireplace    Basment
# 2840             5        Typ           0  NoFireplace     Attchd
# 2846             6        Typ           0  NoFireplace     Attchd
# 2848             5        Typ           1           TA     Attchd
# 2851             9        Typ           1           TA     Attchd
# 2901             6        Typ           2           Gd     Attchd
# 2902             5        Typ           0  NoFireplace     Attchd
# 2909             8        Typ           0  NoFireplace     2Types
#
#       GarageYrBlt GarageFinish  GarageCars  GarageArea GarageQual GarageCond  \
# Id
# 8          1973.0          RFn         2.0       484.0         TA         TA
# 13         1962.0          Unf         1.0       352.0         TA         TA
# 15         1960.0          RFn         1.0       352.0         TA         TA
# 17         1970.0          Fin         2.0       480.0         TA         TA
# 25         1968.0          Unf         1.0       270.0         TA         TA
# 32         1966.0          Unf         1.0       271.0         TA         TA
# 43         1983.0          RFn         2.0       504.0         TA         Gd
# 44         1977.0          Unf         1.0       308.0         TA         TA
# 51         1997.0          Fin         2.0       388.0         TA         TA
# 65         1998.0          RFn         2.0       645.0         TA         TA
# 67         1970.0          RFn         2.0       576.0         TA         TA
# 77         1956.0          Unf         1.0       283.0         TA         TA
# 85         1995.0          Fin         2.0       400.0         TA         TA
# 96         1993.0          Fin         2.0       420.0         TA         TA
# 101        1977.0          RFn         2.0       480.0         TA         TA
# 105        1951.0          Unf         1.0       240.0         TA         TA
# 112        2000.0          Fin         2.0       400.0         TA         TA
# 114        1953.0          Unf         2.0       450.0         TA         TA
# 117        1962.0          Unf         1.0       288.0         TA         TA
# 121        1969.0          Unf         2.0       540.0         TA         TA
# 127        1977.0          RFn         2.0       440.0         TA         TA
# 132        2000.0          RFn         2.0       390.0         TA         TA
# 134        2001.0          Fin         2.0       471.0         TA         TA
# 137        1967.0          RFn         1.0       318.0         TA         TA
# 148        2001.0          Fin         2.0       434.0         TA         TA
# 2707          Y         203           74              0          0
# 2708          Y           0            0              0          0
# 2709          Y           0            0              0          0
# 2710          Y          64            0              0          0
# 2715          Y           0           32              0          0
# 2716          Y           0           50              0          0
# 2725          Y         182           88              0          0
# 2728          Y         154           60              0          0
# 2738          Y           0            0              0          0
# 2739          Y           0           69              0          0
# 2742          Y          80            0              0          0
# 2765          Y         520          102              0          0
# 2808          Y         314           48              0          0
# 2811          Y         284            0              0          0
# 2812          Y         131            0              0          0
# 2813          Y         170            0              0          0
# 2815          N           0            0            116          0
# 2816          Y           0          115            168          0
# 2819          Y         188           36              0          0
# 2840          Y           0          130              0          0
# 2846          Y         320           54              0          0
# 2848          Y          68          166              0          0
# 2851          Y         120           48              0          0
# 2901          Y           0            0              0          0
# 2902          Y           0          173              0          0
# 2909          Y           0            0              0          0
#
#       ScreenPorch  PoolArea  PoolQC    Fence    MiscFeature  MiscVal  MoSold  \
# Id
# 8               0         0  NoPool  NoFence           Shed      350      11
# 13            176         0  NoPool  NoFence  NoMiscFeature        0       9
# 15              0         0  NoPool     GdWo  NoMiscFeature        0       5
# 17              0         0  NoPool  NoFence           Shed      700       3
# 25              0         0  NoPool    MnPrv  NoMiscFeature        0       5
# 32              0         0  NoPool    MnPrv  NoMiscFeature        0       6
# 43              0         0  NoPool    MnPrv  NoMiscFeature        0      12
# 44              0         0  NoPool    MnPrv  NoMiscFeature        0       7
# 51              0         0  NoPool  NoFence  NoMiscFeature        0       7
# 65              0         0  NoPool    GdPrv  NoMiscFeature        0       2
# 67              0         0  NoPool  NoFence  NoMiscFeature        0       7
# 77              0         0  NoPool  NoFence  NoMiscFeature        0       4
# 85              0         0  NoPool  NoFence           Shed      700       5
# 96              0         0  NoPool  NoFence           Shed      480       4
# 101             0         0  NoPool  NoFence  NoMiscFeature        0       2
# 105           184         0  NoPool  NoFence  NoMiscFeature        0       6
# 112             0         0  NoPool  NoFence  NoMiscFeature        0       4
# 114             0         0  NoPool    MnPrv  NoMiscFeature        0      10
# 117             0         0  NoPool  NoFence  NoMiscFeature        0       9
# 121             0         0  NoPool  NoFence  NoMiscFeature        0      10
# 127             0         0  NoPool  NoFence  NoMiscFeature        0       2
# 132             0         0  NoPool  NoFence  NoMiscFeature        0       7
# 134             0         0  NoPool  NoFence  NoMiscFeature        0       6
# 137             0         0  NoPool  NoFence  NoMiscFeature        0       7
# 148             0         0  NoPool  NoFence  NoMiscFeature        0       5
# 150             0         0  NoPool  NoFence  NoMiscFeature        0       4
# 153             0         0  NoPool     GdWo  NoMiscFeature        0       6
# 154             0         0  NoPool  NoFence  NoMiscFeature        0       3
# 161             0         0  NoPool  NoFence  NoMiscFeature        0       6
# 167           142         0  NoPool     GdWo  NoMiscFeature        0      11
# ...           ...       ...     ...      ...            ...      ...     ...
# 2685            0         0  NoPool  NoFence  NoMiscFeature        0      10
# 2701            0         0  NoPool  NoFence  NoMiscFeature        0       7
# 2704            0         0  NoPool    MnPrv  NoMiscFeature        0       3
# 2705            0         0  NoPool    MnPrv  NoMiscFeature        0       7
# 2707            0         0  NoPool  NoFence  NoMiscFeature        0      10
# 2708            0         0  NoPool    MnPrv  NoMiscFeature        0       1
# 2709            0         0  NoPool     GdWo  NoMiscFeature        0       4
# 2710            0         0  NoPool  NoFence  NoMiscFeature        0       6
# 2715            0         0  NoPool  NoFence  NoMiscFeature        0       6
# 2716            0         0  NoPool  NoFence  NoMiscFeature        0       7
# 2725            0         0  NoPool  NoFence  NoMiscFeature        0       3
# 2728            0         0  NoPool  NoFence  NoMiscFeature        0       4
# 2738            0         0  NoPool  NoFence  NoMiscFeature        0      10
# 2739            0         0  NoPool  NoFence  NoMiscFeature        0      11
# 2742            0         0  NoPool  NoFence  NoMiscFeature        0      12
# 2765            0         0  NoPool  NoFence  NoMiscFeature        0       9
# 2808            0         0  NoPool  NoFence  NoMiscFeature        0       6
# 2811            0         0  NoPool    MnPrv  NoMiscFeature        0       7
# 2812          180         0  NoPool    GdPrv  NoMiscFeature        0       7
# 2813            0         0  NoPool  NoFence  NoMiscFeature        0       8
# 2815            0         0  NoPool  NoFence  NoMiscFeature        0       4
# 2816            0         0  NoPool  NoFence  NoMiscFeature        0       6
# 2819          200         0  NoPool  NoFence  NoMiscFeature        0       4
# 2840            0         0  NoPool  NoFence  NoMiscFeature        0       5
# 2846            0         0  NoPool  NoFence  NoMiscFeature        0       7
# 2848            0         0  NoPool  NoFence  NoMiscFeature        0       6
# 2851            0         0  NoPool  NoFence  NoMiscFeature        0       8
# 2901          138         0  NoPool  NoFence  NoMiscFeature        0       3
# 2902            0         0  NoPool  NoFence  NoMiscFeature        0      10
# 2909            0         0  NoPool  NoFence  NoMiscFeature        0       3
#
#       YrSold SaleType SaleCondition
# Id
# 8       2009       WD        Normal
# 13      2008       WD        Normal
# 15      2008       WD        Normal
# 17      2010       WD        Normal
# 25      2010       WD        Normal
# 32      2008       WD        Normal
# 43      2007       WD        Normal
# 44      2008       WD        Normal
# 51      2007       WD        Normal
# 65      2009       WD        Normal
# 67      2010       WD        Normal
# 77      2008       WD        Normal
# 85      2009       WD        Normal
# 96      2009       WD        Normal
# 101     2010       WD        Normal
# 105     2007       WD        Normal
# 112     2010       WD        Normal
# 114     2007      COD       Abnorml
# 117     2009       WD        Normal
# 121     2006       WD        Normal
# 127     2007       WD        Normal
# 132     2009       WD        Normal
# 134     2009       WD        Normal
# 137     2007       WD        Normal
# 148     2010       WD        Normal
# 150     2006       WD        Normal
# 153     2006       WD        Normal
# 154     2008       WD        Normal
# 161     2008       WD        Normal
# 167     2009      COD        Normal
# ...      ...      ...           ...
# 2685    2006       WD        Normal
# 2701    2006       WD        Normal
# 2704    2006       WD        Normal
# 2705    2006       WD        Normal
# 2707    2006       WD        Normal
# 2708    2006       WD        Normal
# 2709    2006       WD        Normal
# 2710    2006       WD        Normal
# 2715    2006       WD        Normal
# 2716    2006       WD        Normal
# 2725    2006       WD        Normal
# 2728    2006       WD        Normal
# 2738    2006       WD        Normal
# 2739    2006       WD        Normal
# 2742    2006       WD        Normal
# 2765    2006       WD        Normal
# 2808    2006       WD        Normal
# 2811    2006       WD        Normal
# 2812    2006       WD        Normal
# 2813    2006       WD        Normal
# 2815    2006       WD        Normal
# 2816    2006       WD        Normal
# 2819    2006       WD        Normal
# 2840    2006       WD        Normal
# 2846    2006       WD        Normal
# 2848    2006       WD        Normal
# 2851    2006       WD        Normal
# 2901    2006       WD        Alloca
# 2902    2006       WD        Normal
# 2909    2006       WD        Normal
#
# [486 rows x 79 columns]

# %%
combined_df["LotFrontage"].describe()
# Out:
# count    2433.000000
# mean       69.305795
# std        23.344905
# min        21.000000
# 25%        59.000000
# 50%        68.000000
# 75%        80.000000
# max       313.000000
# Name: LotFrontage, dtype: float64

# %% [markdown]
# OK LotFrontage is always an integer and looks like 1-ft resolution. Interestingly there are no '0' values. This suggests that NaN shouldn't be interpreted as 0. <br>
# One thing that may be helpful is to look at lot depth as well. We can add a new LotDepth feature. This is simple for regular lots which we'll presume are rectangular. Theory is that many lots may have different width but will be same depth from the street. The depth calculation depends on LotConfig as well (Inside, Corner, CulDSac, FR2, FR3). Presumably Corner and FR2 should be about the same for calculation purpose...<br>
# As a first-pass approach we can group properties by area, shape and config. Lots within these three criteria _should_ have same LotFrontage.

# %%
# Use groupby to take median value of LotFrontage in each group and fill in missing per group.
# Usually, and especially regularly shaped lots, will all be similar size. Grouping by lot area and shape will allow us to copy
# the missing LotFrontage calculation from a lot that looks same size/shape and in same neighborhood.
lot_groups = combined_df.groupby(["LotArea","LotShape","LotConfig"])
#for name, group in lot_groups:
#    print(name)
#    print(len(group))

# %%
combined_df["LotFrontage"] = lot_groups["LotFrontage"].transform(lambda x: x.fillna(x.median()))

# %%
# Create three new features - LotWidth, LotDepth and LotAR.
# LotWidth is intended to represent width of the lot. (calculated from LotFrontage.)
# LotDepth is intended to represent lot depth from the street.
# LotAR is intended to represent lot aspect ratio (width/depth)
#LotConfig: Lot configuration
#       Inside	Inside lot
#       Corner	Corner lot
#       CulDSac	Cul-de-sac
#       FR2	Frontage on 2 sides of property
#       FR3	Frontage on 3 sides of property
# corner lots should have frontage one 2 sides so need to divide frontage by 2 before calculating.
# Todo: Need to verify this assumption.
combined_df.loc[combined_df["LotConfig"] == "Inside","LotWidth"] = combined_df.loc[combined_df["LotConfig"] == "Inside","LotFrontage"]
combined_df.loc[combined_df["LotConfig"] == "Corner","LotWidth"] = combined_df.loc[combined_df["LotConfig"] == "Corner","LotFrontage"]/2
combined_df.loc[combined_df["LotConfig"] == "CulDSac","LotWidth"] = combined_df.loc[combined_df["LotConfig"] == "CulDSac","LotFrontage"]
combined_df.loc[combined_df["LotConfig"] == "FR2","LotWidth"] = combined_df.loc[combined_df["LotConfig"] == "FR2","LotFrontage"]/2
combined_df.loc[combined_df["LotConfig"] == "FR3","LotWidth"] = combined_df.loc[combined_df["LotConfig"] == "FR3","LotFrontage"]/3

# Todo: CulDSac depth could be calculated more accurately using donut area approximation
combined_df.loc[combined_df["LotConfig"] == "Inside","LotDepth"] = combined_df.loc[combined_df["LotConfig"] == "Inside","LotArea"] / combined_df.loc[combined_df["LotConfig"] == "Inside","LotFrontage"]
combined_df.loc[combined_df["LotConfig"] == "Corner","LotDepth"] = combined_df.loc[combined_df["LotConfig"] == "Corner","LotArea"] / (combined_df.loc[combined_df["LotConfig"] == "Corner","LotFrontage"]/2)
combined_df.loc[combined_df["LotConfig"] == "CulDSac","LotDepth"] = combined_df.loc[combined_df["LotConfig"] == "CulDSac","LotArea"] / combined_df.loc[combined_df["LotConfig"] == "CulDSac","LotFrontage"]
combined_df.loc[combined_df["LotConfig"] == "FR2","LotDepth"] = combined_df.loc[combined_df["LotConfig"] == "FR2","LotArea"] / (combined_df.loc[combined_df["LotConfig"] == "FR2","LotFrontage"]/2)
combined_df.loc[combined_df["LotConfig"] == "FR3","LotDepth"] = combined_df.loc[combined_df["LotConfig"] == "FR3","LotArea"] / (combined_df.loc[combined_df["LotConfig"] == "FR3","LotFrontage"]/3)
    
# round LotWidth down to nearest integer
combined_df["LotWidth"] = np.floor(combined_df["LotWidth"])
# round LotDepth to nearest 5ft resolution
def round_down_to_nearest(self, n):
    return (self // n) * n
# end def
combined_df["LotDepth"] = combined_df["LotDepth"].apply(lambda x: round_down_to_nearest(x, 5))

# Now calculate AR with rounded values., and round it to 2 digits
combined_df.loc[combined_df["LotConfig"] == "Inside","LotAR"] = ((combined_df.loc[combined_df["LotConfig"] == "Inside","LotFrontage"]) / combined_df.loc[combined_df["LotConfig"] == "Inside","LotDepth"]).round(2)
combined_df.loc[combined_df["LotConfig"] == "Corner","LotAR"] = ((combined_df.loc[combined_df["LotConfig"] == "Corner","LotFrontage"]/2) / combined_df.loc[combined_df["LotConfig"] == "Corner","LotDepth"]).round(2)
combined_df.loc[combined_df["LotConfig"] == "CulDSac","LotAR"] = ((combined_df.loc[combined_df["LotConfig"] == "CulDSac","LotFrontage"]) / combined_df.loc[combined_df["LotConfig"] == "CulDSac","LotDepth"]).round(2)
combined_df.loc[combined_df["LotConfig"] == "FR2","LotAR"] = ((combined_df.loc[combined_df["LotConfig"] == "FR2","LotFrontage"]/2) / combined_df.loc[combined_df["LotConfig"] == "FR2","LotDepth"]).round(2)
combined_df.loc[combined_df["LotConfig"] == "FR3","LotAR"] = ((combined_df.loc[combined_df["LotConfig"] == "FR3","LotFrontage"]/3) / combined_df.loc[combined_df["LotConfig"] == "FR3","LotDepth"]).round(2)

# %%
combined_df.loc[combined_df["LotFrontage"].isnull(),("LotShape","LotFrontage","LotArea","LotConfig","LandContour","LandSlope","Neighborhood","HouseStyle")]
# Out:
#      LotShape  LotFrontage  LotArea LotConfig LandContour LandSlope  \
# Id
# 13        IR2          NaN    12968    Inside         Lvl       Gtl
# 51        IR2          NaN    13869    Corner         Lvl       Gtl
# 96        IR2          NaN     9765    Corner         Lvl       Gtl
# 127       IR1          NaN     4928    Inside         Lvl       Gtl
# 250       IR2          NaN   159000   CulDSac         Low       Sev
# 308       IR1          NaN     7920    Inside         Lvl       Gtl
# 365       IR1          NaN    18800       FR2         Lvl       Gtl
# 385       IR2          NaN    53107    Corner         Low       Mod
# 422       IR1          NaN    16635       FR2         Lvl       Gtl
# 542       Reg          NaN    11000       FR2         Lvl       Gtl
# 612       IR1          NaN    10395       FR2         Lvl       Gtl
# 661       Reg          NaN    12384   CulDSac         Lvl       Gtl
# 688       IR2          NaN     5105       FR2         Lvl       Gtl
# 707       IR2          NaN   115149   CulDSac         Low       Sev
# 829       IR2          NaN    28698   CulDSac         Low       Sev
# 869       IR2          NaN    14762    Corner         Lvl       Gtl
# 1007      IR3          NaN    12155    Inside         Lvl       Gtl
# 1058      IR2          NaN    29959       FR2         Lvl       Gtl
# 1085      IR2          NaN    13031    Corner         Lvl       Gtl
# 1165      IR1          NaN    16157       FR2         Lvl       Gtl
# 1181      IR2          NaN    11170    Corner         Lvl       Gtl
# 1347      IR2          NaN    20781   CulDSac         Lvl       Gtl
# 1349      IR3          NaN    16196    Inside         Low       Gtl
# 1432      IR1          NaN     4928    Inside         Lvl       Gtl
# 1696      IR2          NaN    15896   CulDSac         Lvl       Gtl
# 1834      IR2          NaN     5775    Corner         Bnk       Mod
# 1937      IR2          NaN    15038    Corner         Lvl       Gtl
# 1942      Reg          NaN    14067       FR3         Lvl       Gtl
# 1958      IR1          NaN    14311       FR3         Lvl       Gtl
# 1997      Reg          NaN    11000       FR2         Lvl       Gtl
# 2129      IR1          NaN     6291    Inside         Lvl       Gtl
# 2156      IR3          NaN     9771    Corner         Lvl       Gtl
# 2164      IR2          NaN    11454    Corner         Lvl       Gtl
# 2223      IR2          NaN    23730    Inside         Lvl       Gtl
# 2251      IR1          NaN    56600    Inside         Low       Gtl
# 2358      IR2          NaN    11613    Corner         Lvl       Gtl
# 2536      IR3          NaN    15295    Corner         Lvl       Gtl
# 2612      IR2          NaN    11000    Corner         Lvl       Gtl
# 2635      IR1          NaN    10464       FR3         Lvl       Gtl
# 2678      IR1          NaN    12104       FR3         Lvl       Gtl
#
#      Neighborhood HouseStyle
# Id
# 13         Sawyer     1Story
# 51        Gilbert     2Story
# 96        Gilbert     2Story
# 127       NPkVill     1Story
# 250       ClearCr     1.5Fin
# 308        IDOTRR     1.5Fin
# 365        NWAmes     2Story
# 385       ClearCr     2Story
# 422        NWAmes     1Story
# 542       NoRidge     2Story
# 612        NWAmes       SLvl
# 661        NWAmes     2Story
# 688       Somerst     2Story
# 707       ClearCr     1Story
# 829       ClearCr     2Story
# 869       Gilbert     2Story
# 1007        NAmes     1Story
# 1058      NoRidge     2Story
# 1085      Gilbert     2Story
# 1165      Veenker       SLvl
# 1181       Timber     2Story
# 1347       NWAmes     1Story
# 1349      SawyerW     1Story
# 1432      NPkVill     1Story
# 1696      Gilbert     2Story
# 1834      OldTown     2Story
# 1937      Gilbert     2Story
# 1942      Gilbert     2Story
# 1958       NWAmes     2Story
# 1997      NoRidge     2Story
# 2129       IDOTRR     1Story
# 2156      SawyerW     2Story
# 2164      SawyerW       SLvl
# 2223      Mitchel     1Story
# 2251       IDOTRR     2.5Unf
# 2358      SawyerW     2Story
# 2536      CollgCr     2Story
# 2612      Mitchel     1Story
# 2635       NWAmes     SFoyer
# 2678      Gilbert     2Story

# %%
missing_cnt = combined_df.isnull().sum()
missing = missing_cnt[missing_cnt > 0] 
print(missing)
# Out:
# LotFrontage    432
# dtype: int64

# %%
# Still quite a lot of missing LotFrontage. Let's focus on regularly shaped lots first and inspect the properties...
combined_df.loc[(combined_df["LotShape"] == "Reg") & (combined_df["Neighborhood"] == "NWAmes"),("LotShape","LotFrontage","LotArea","LotDepth","LotAR","LotConfig","LandContour","LandSlope","Neighborhood","HouseStyle")]
# Out:
#      LotShape  LotFrontage  LotArea  LotDepth  LotAR LotConfig LandContour  \
# Id
# 136       Reg         80.0    10400     130.0   0.62    Inside         Lvl
# 223       Reg         85.0    11475     135.0   0.63    Inside         Lvl
# 246       Reg         80.0    10400     130.0   0.62    Inside         Lvl
# 299       Reg         90.0    11700     130.0   0.69    Inside         Lvl
# 320       Reg         80.0    14115     175.0   0.46    Inside         Lvl
# 339       Reg         91.0    14145     310.0   0.15    Corner         Lvl
# 456       Reg         80.0     9600     120.0   0.67    Inside         Lvl
# 472       Reg         92.0    11952     125.0   0.74    Inside         Lvl
# 543       Reg         78.0    10140     130.0   0.60    Inside         Lvl
# 622       Reg         90.0    10800     120.0   0.75    Inside         Lvl
# 625       Reg         80.0    10400     130.0   0.62    Inside         Lvl
# 633       Reg         85.0    11900     140.0   0.61    Inside         Lvl
# 644       Reg         80.0    10793     130.0   0.62    Inside         Lvl
# 661       Reg          NaN    12384       NaN    NaN   CulDSac         Lvl
# 702       Reg         80.0     9600     120.0   0.67    Inside         Lvl
# 716       Reg         78.0    10140     130.0   0.60    Inside         Lvl
# 718       Reg         80.0    10000     125.0   0.64    Inside         Lvl
# 767       Reg         80.0    10421     130.0   0.62    Inside         Lvl
# 786       Reg         80.0     9790     120.0   0.67    Inside         Lvl
# 811       Reg         78.0    10140     130.0   0.60    Inside         Lvl
# 859       Reg         80.0    10400     130.0   0.62    Inside         Lvl
# 925       Reg         79.0    10240     125.0   0.63    Inside         Lvl
# 928       Reg         90.0     9900     110.0   0.82    Inside         Lvl
# 950       Reg         78.0     9360     120.0   0.65    Inside         Lvl
# 1016      Reg         70.0     8400     120.0   0.58    Inside         Lvl
# 1042      Reg         80.0     9130     110.0   0.73    Inside         Lvl
# 1045      Reg         80.0     9600     120.0   0.67    Inside         Lvl
# 1056      Reg        104.0    11361     105.0   0.99    Inside         Lvl
# 1072      Reg         78.0    11700     150.0   0.52    Inside         Lvl
# 1081      Reg         80.0    11040     135.0   0.59    Inside         Lvl
# ...       ...          ...      ...       ...    ...       ...         ...
# 1639      Reg         80.0    10928     135.0   0.59    Inside         Lvl
# 1641      Reg         80.0    11088     135.0   0.59    Inside         Lvl
# 1646      Reg         78.0    10140     130.0   0.60    Inside         Lvl
# 1748      Reg         80.0    10400     130.0   0.62    Inside         Lvl
# 1749      Reg         80.0     9600     120.0   0.67    Inside         Lvl
# 1750      Reg         75.0     9000     120.0   0.62    Inside         Lvl
# 1754      Reg         80.0     9600     120.0   0.67    Inside         Lvl
# 1755      Reg         80.0    16500     205.0   0.39    Inside         Lvl
# 1952      Reg         85.0    14450     170.0   0.50    Inside         Lvl
# 1953      Reg         90.0    13068     290.0   0.16    Corner         Lvl
# 1954      Reg         80.0    10400     130.0   0.62    Inside         Lvl
# 1955      Reg         75.0     9743     125.0   0.60    Inside         Lvl
# 1957      Reg         80.0    10400     130.0   0.62    Inside         Lvl
# 2044      Reg         85.0    11050     130.0   0.65    Inside         Lvl
# 2046      Reg         75.0     9750     130.0   0.58    Inside         Lvl
# 2270      Reg         78.0    12090     155.0   0.50    Inside         Lvl
# 2271      Reg         93.0    12299     130.0   0.72    Inside         Lvl
# 2273      Reg         79.0    11850     300.0   0.13       FR2         Lvl
# 2274      Reg         80.0    10400     130.0   0.62    Inside         Lvl
# 2277      Reg         80.0     8000     100.0   0.80    Inside         Lvl
# 2378      Reg         78.0    11700     150.0   0.52    Inside         Lvl
# 2379      Reg         80.0     8000     100.0   0.80    Inside         Lvl
# 2381      Reg        130.0    11700     180.0   0.36    Corner         Lvl
# 2383      Reg         80.0     9547     115.0   0.70    Inside         Lvl
# 2384      Reg         78.0    10530     135.0   0.58    Inside         Lvl
# 2386      Reg         80.0    10800     135.0   0.59    Inside         Lvl
# 2636      Reg         81.0    10530     130.0   0.62    Inside         Lvl
# 2639      Reg         81.0    10530     130.0   0.62    Inside         Lvl
# 2640      Reg         80.0    10000     125.0   0.64    Inside         Lvl
# 2720      Reg         78.0    10140     130.0   0.60    Inside         Lvl
#
#      LandSlope Neighborhood HouseStyle
# Id
# 136        Gtl       NWAmes     1Story
# 223        Gtl       NWAmes     2Story
# 246        Gtl       NWAmes     1Story
# 299        Gtl       NWAmes     2Story
# 320        Gtl       NWAmes       SLvl
# 339        Gtl       NWAmes     1Story
# 456        Gtl       NWAmes     1Story
# 472        Gtl       NWAmes     2Story
# 543        Gtl       NWAmes     1Story
# 622        Gtl       NWAmes     2Story
# 625        Gtl       NWAmes     2Story
# 633        Gtl       NWAmes     1Story
# 644        Gtl       NWAmes     2Story
# 661        Gtl       NWAmes     2Story
# 702        Gtl       NWAmes     1Story
# 716        Gtl       NWAmes     1Story
# 718        Gtl       NWAmes     1Story
# 767        Gtl       NWAmes     2Story
# 786        Gtl       NWAmes     1Story
# 811        Gtl       NWAmes     1Story
# 859        Gtl       NWAmes     1Story
# 925        Gtl       NWAmes     1Story
# 928        Gtl       NWAmes     2Story
# 950        Gtl       NWAmes     1Story
# 1016       Gtl       NWAmes     2Story
# 1042       Gtl       NWAmes     2Story
# 1045       Gtl       NWAmes     1Story
# 1056       Gtl       NWAmes     1Story
# 1072       Gtl       NWAmes     2Story
# 1081       Gtl       NWAmes     1Story
# ...        ...          ...        ...
# 1639       Gtl       NWAmes     1Story
# 1641       Gtl       NWAmes     1Story
# 1646       Gtl       NWAmes     1Story
# 1748       Gtl       NWAmes     2Story
# 1749       Gtl       NWAmes     1Story
# 1750       Gtl       NWAmes     1Story
# 1754       Gtl       NWAmes     2Story
# 1755       Gtl       NWAmes     SFoyer
# 1952       Gtl       NWAmes     1Story
# 1953       Gtl       NWAmes     1Story
# 1954       Gtl       NWAmes     2Story
# 1955       Gtl       NWAmes     2Story
# 1957       Gtl       NWAmes     1Story
# 2044       Gtl       NWAmes     1Story
# 2046       Gtl       NWAmes     1Story
# 2270       Gtl       NWAmes     2Story
# 2271       Gtl       NWAmes     1Story
# 2273       Gtl       NWAmes     1Story
# 2274       Gtl       NWAmes     1Story
# 2277       Gtl       NWAmes     2Story
# 2378       Gtl       NWAmes     1Story
# 2379       Gtl       NWAmes     2Story
# 2381       Gtl       NWAmes     1Story
# 2383       Gtl       NWAmes     1Story
# 2384       Gtl       NWAmes     2Story
# 2386       Gtl       NWAmes     1Story
# 2636       Gtl       NWAmes     2Story
# 2639       Gtl       NWAmes       SLvl
# 2640       Gtl       NWAmes     1Story
# 2720       Gtl       NWAmes     1Story
#
# [73 rows x 10 columns]

# %%
# Having LotDepth looks to be helpful. Many plots with different LotFrontage (width) have same depth, as suspected.
# Most plots have depth calculated landing up at 5ft resolution tho not all. May consider rounding LotDepth to nearest 5ft.
# This looks to be especially true for regularly shaped (rectangular) plots. Irregular plots may make more sense to round down ?
combined_df.loc[(combined_df["LotShape"] == "IR1") & (combined_df["Neighborhood"] == "NWAmes"),("LotShape","LotFrontage","LotArea","LotDepth","LotAR","LotConfig","LandContour","LandSlope","Neighborhood","HouseStyle")]
# Out:
#      LotShape  LotFrontage  LotArea  LotDepth  LotAR LotConfig LandContour  \
# Id
# 8         IR1         88.0    10382     235.0   0.19    Corner         Lvl
# 101       IR1         81.0    10603     130.0   0.62    Inside         Lvl
# 110       IR1        105.0    11751     110.0   0.95    Inside         Lvl
# 125       IR1         48.0    17043     355.0   0.14   CulDSac         Lvl
# 153       IR1         52.0    14803     280.0   0.19   CulDSac         Lvl
# 266       IR1         78.0    12090     155.0   0.50    Inside         Lvl
# 294       IR1        134.0    16659     245.0   0.27    Corner         Lvl
# 317       IR1         94.0    13005     275.0   0.17    Corner         Lvl
# 365       IR1          NaN    18800       NaN    NaN       FR2         Lvl
# 422       IR1          NaN    16635       NaN    NaN       FR2         Lvl
# 488       IR1         70.0    12243     170.0   0.41    Inside         Lvl
# 517       IR1         88.0    10448     235.0   0.19    Corner         Lvl
# 546       IR1         88.0    13837     310.0   0.14    Corner         Lvl
# 612       IR1          NaN    10395       NaN    NaN       FR2         Lvl
# 746       IR1         81.0     8963     110.0   0.74    Inside         Lvl
# 860       IR1         87.0    11029     250.0   0.17    Corner         Lvl
# 926       IR1         88.0    15611     350.0   0.13    Corner         Lvl
# 962       IR1         88.0    12227     275.0   0.16    Corner         Lvl
# 989       IR1         81.0    12046     145.0   0.56    Inside         Lvl
# 998       IR1         81.0    11717     140.0   0.58    Inside         Lvl
# 1004      IR1         88.0    11500     260.0   0.17    Corner         Lvl
# 1100      IR1         82.0    11880     140.0   0.59    Inside         Lvl
# 1142      IR1         52.0    10304     195.0   0.27   CulDSac         Lvl
# 1272      IR1         81.0     9156     110.0   0.74    Inside         Lvl
# 1277      IR1         52.0    12936     245.0   0.21   CulDSac         Lvl
# 1278      IR1         52.0    17871     340.0   0.15   CulDSac         Lvl
# 1337      IR1         87.0     9246     105.0   0.83    Inside         Lvl
# 1356      IR1        102.0    10192      95.0   1.07    Inside         Lvl
# 1387      IR1         80.0    16692     205.0   0.39    Inside         Lvl
# 1410      IR1         46.0    20544     445.0   0.10   CulDSac         Lvl
# 1430      IR1         88.0    12546     285.0   0.15    Corner         Lvl
# 1506      IR1         81.0    10456     125.0   0.65    Inside         Lvl
# 1508      IR1         81.0    18837     230.0   0.35    Inside         Lvl
# 1638      IR1         81.0    13250     160.0   0.51    Inside         Lvl
# 1640      IR1         81.0    12388     150.0   0.54    Inside         Lvl
# 1645      IR1         52.0     9373     180.0   0.29   CulDSac         Lvl
# 1647      IR1         85.0    11050     260.0   0.16    Corner         Lvl
# 1747      IR1         52.0    12732     240.0   0.22   CulDSac         Lvl
# 1751      IR1         81.0    13774     170.0   0.48    Inside         Lvl
# 1949      IR1         63.0    12680     200.0   0.32    Inside         Lvl
# 1950      IR1         81.0    10825     130.0   0.62    Inside         Lvl
# 1951      IR1         56.0    18559     330.0   0.17   CulDSac         Lvl
# 1956      IR1         88.0    12511     280.0   0.16    Corner         Lvl
# 1958      IR1          NaN    14311       NaN    NaN       FR3         Lvl
# 2043      IR1         81.0    11104     135.0   0.60    Inside         Lvl
# 2045      IR1         52.0    15387     295.0   0.18   CulDSac         Lvl
# 2050      IR1         81.0    13355     160.0   0.51    Inside         Lvl
# 2269      IR1         81.0    10960     135.0   0.60    Inside         Lvl
# 2272      IR1         61.0    11339     185.0   0.33    Inside         Lvl
# 2275      IR1        128.0    13001     100.0   1.28    Inside         Lvl
# 2276      IR1         64.0     8991     140.0   0.46   CulDSac         Lvl
# 2380      IR1         81.0     8723     105.0   0.77    Inside         Lvl
# 2382      IR1        108.0    11358     210.0   0.26    Corner         Lvl
# 2385      IR1         88.0    10738     240.0   0.18    Corner         Lvl
# 2635      IR1          NaN    10464       NaN    NaN       FR3         Lvl
# 2637      IR1         81.0     9927     120.0   0.68    Inside         Lvl
# 2719      IR1         79.0    13110     330.0   0.12    Corner         Lvl
#
#      LandSlope Neighborhood HouseStyle
# Id
# 8          Gtl       NWAmes     2Story
# 101        Gtl       NWAmes     1Story
# 110        Gtl       NWAmes     1Story
# 125        Gtl       NWAmes     1Story
# 153        Gtl       NWAmes     2Story
# 266        Gtl       NWAmes     1Story
# 294        Gtl       NWAmes     2Story
# 317        Gtl       NWAmes     2Story
# 365        Gtl       NWAmes     2Story
# 422        Gtl       NWAmes     1Story
# 488        Gtl       NWAmes     1Story
# 517        Gtl       NWAmes       SLvl
# 546        Gtl       NWAmes     1.5Fin
# 612        Gtl       NWAmes       SLvl
# 746        Gtl       NWAmes     2Story
# 860        Gtl       NWAmes     2Story
# 926        Gtl       NWAmes     1Story
# 962        Gtl       NWAmes     2Story
# 989        Gtl       NWAmes     2Story
# 998        Gtl       NWAmes     1Story
# 1004       Gtl       NWAmes     1Story
# 1100       Gtl       NWAmes     1Story
# 1142       Gtl       NWAmes     2Story
# 1272       Gtl       NWAmes     1Story
# 1277       Gtl       NWAmes     2Story
# 1278       Gtl       NWAmes       SLvl
# 1337       Gtl       NWAmes     1Story
# 1356       Gtl       NWAmes       SLvl
# 1387       Gtl       NWAmes     2Story
# 1410       Gtl       NWAmes     2Story
# 1430       Gtl       NWAmes     1Story
# 1506       Gtl       NWAmes     1Story
# 1508       Gtl       NWAmes     1.5Fin
# 1638       Gtl       NWAmes     2Story
# 1640       Gtl       NWAmes     2Story
# 1645       Gtl       NWAmes     1Story
# 1647       Gtl       NWAmes     1Story
# 1747       Gtl       NWAmes     2Story
# 1751       Gtl       NWAmes     2Story
# 1949       Gtl       NWAmes     1Story
# 1950       Gtl       NWAmes     1Story
# 1951       Gtl       NWAmes     1Story
# 1956       Gtl       NWAmes     2Story
# 1958       Gtl       NWAmes     2Story
# 2043       Gtl       NWAmes       SLvl
# 2045       Gtl       NWAmes     1Story
# 2050       Gtl       NWAmes     2Story
# 2269       Gtl       NWAmes     1Story
# 2272       Gtl       NWAmes     2Story
# 2275       Gtl       NWAmes     1Story
# 2276       Gtl       NWAmes       SLvl
# 2380       Gtl       NWAmes     SFoyer
# 2382       Gtl       NWAmes     1Story
# 2385       Gtl       NWAmes     1Story
# 2635       Gtl       NWAmes     SFoyer
# 2637       Gtl       NWAmes     SFoyer
# 2719       Gtl       NWAmes     1Story

# %%
ax = plot_ann_barh(combined_df.loc[(combined_df["LotShape"] == "Reg"),"LotDepth"].value_counts().head(30), 
                   xlim=max(combined_df.loc[(combined_df["LotShape"] == "Reg"),"LotDepth"].value_counts()), 
                   title='Count of LotDepth calculations for LotShape == Reg')

# %%
ax = plot_ann_barh(combined_df.loc[(combined_df["LotShape"] == "IR1"),"LotDepth"].value_counts().head(30), 
                   xlim=max(combined_df.loc[(combined_df["LotShape"] == "IR1"),"LotDepth"].value_counts()), 
                   title='Count of LotDepth calculations for LotShape == IR1')

# %%
ax = plot_ann_barh(combined_df.loc[(combined_df["LotShape"] == "IR2"),"LotDepth"].value_counts().head(30), 
                   xlim=max(combined_df.loc[(combined_df["LotShape"] == "IR2"),"LotDepth"].value_counts()), 
                   title='Count of LotDepth calculations for LotShape == IR2')

# %%
ax = plot_ann_barh(combined_df.loc[(combined_df["LotShape"] == "IR3"),"LotDepth"].value_counts().head(30), 
                   xlim=max(combined_df.loc[(combined_df["LotShape"] == "IR3"),"LotDepth"].value_counts()), 
                   title='Count of LotDepth calculations for LotShape == IR3')

# %%
# From above plots it's clear that regularly shaped lots should have their depth calculation binned to 5ft resolution. 
# Irregular plots, not so clear.
combined_df.loc[((combined_df["LotShape"] == "IR1") & (combined_df["LotDepth"] < 350)),"LotDepth"].hist(bins=25)

# %%
combined_df.loc[((combined_df["LotShape"] == "IR2") & (combined_df["LotDepth"] < 500)),"LotDepth"].hist(bins=25)

# %%
combined_df.loc[((combined_df["LotShape"] == "IR3") & (combined_df["LotDepth"] < 500)),"LotDepth"].hist(bins=25)

# %%
# Actually groupby neighborhood instead of lotarea for next-level imputation
# TODO: Instead of filling with median within the group, the median should be scaled by LotArea somehow first...
# TODO: Should add a binary feature to indicate imputed LotFrontage values.
combined_df["LotFrontage"] = combined_df.groupby(["Neighborhood","LotShape","LotConfig"])["LotFrontage"].transform(lambda x: x.fillna(x.median()))

# %%
missing_cnt = combined_df.isnull().sum()
missing = missing_cnt[missing_cnt > 0] 
print(missing)
# Out:
# LotFrontage    40
# dtype: int64

# %%
# Down to 40, that's pretty good. Let's inspect...
combined_df.loc[combined_df["LotFrontage"].isnull(),("LotShape","LotFrontage","LotArea","LotConfig","LandContour","LandSlope","Neighborhood","HouseStyle")]
# Out:
#      LotShape  LotFrontage  LotArea LotConfig LandContour LandSlope  \
# Id
# 13        IR2          NaN    12968    Inside         Lvl       Gtl
# 51        IR2          NaN    13869    Corner         Lvl       Gtl
# 96        IR2          NaN     9765    Corner         Lvl       Gtl
# 127       IR1          NaN     4928    Inside         Lvl       Gtl
# 250       IR2          NaN   159000   CulDSac         Low       Sev
# 308       IR1          NaN     7920    Inside         Lvl       Gtl
# 365       IR1          NaN    18800       FR2         Lvl       Gtl
# 385       IR2          NaN    53107    Corner         Low       Mod
# 422       IR1          NaN    16635       FR2         Lvl       Gtl
# 542       Reg          NaN    11000       FR2         Lvl       Gtl
# 612       IR1          NaN    10395       FR2         Lvl       Gtl
# 661       Reg          NaN    12384   CulDSac         Lvl       Gtl
# 688       IR2          NaN     5105       FR2         Lvl       Gtl
# 707       IR2          NaN   115149   CulDSac         Low       Sev
# 829       IR2          NaN    28698   CulDSac         Low       Sev
# 869       IR2          NaN    14762    Corner         Lvl       Gtl
# 1007      IR3          NaN    12155    Inside         Lvl       Gtl
# 1058      IR2          NaN    29959       FR2         Lvl       Gtl
# 1085      IR2          NaN    13031    Corner         Lvl       Gtl
# 1165      IR1          NaN    16157       FR2         Lvl       Gtl
# 1181      IR2          NaN    11170    Corner         Lvl       Gtl
# 1347      IR2          NaN    20781   CulDSac         Lvl       Gtl
# 1349      IR3          NaN    16196    Inside         Low       Gtl
# 1432      IR1          NaN     4928    Inside         Lvl       Gtl
# 1696      IR2          NaN    15896   CulDSac         Lvl       Gtl
# 1834      IR2          NaN     5775    Corner         Bnk       Mod
# 1937      IR2          NaN    15038    Corner         Lvl       Gtl
# 1942      Reg          NaN    14067       FR3         Lvl       Gtl
# 1958      IR1          NaN    14311       FR3         Lvl       Gtl
# 1997      Reg          NaN    11000       FR2         Lvl       Gtl
# 2129      IR1          NaN     6291    Inside         Lvl       Gtl
# 2156      IR3          NaN     9771    Corner         Lvl       Gtl
# 2164      IR2          NaN    11454    Corner         Lvl       Gtl
# 2223      IR2          NaN    23730    Inside         Lvl       Gtl
# 2251      IR1          NaN    56600    Inside         Low       Gtl
# 2358      IR2          NaN    11613    Corner         Lvl       Gtl
# 2536      IR3          NaN    15295    Corner         Lvl       Gtl
# 2612      IR2          NaN    11000    Corner         Lvl       Gtl
# 2635      IR1          NaN    10464       FR3         Lvl       Gtl
# 2678      IR1          NaN    12104       FR3         Lvl       Gtl
#
#      Neighborhood HouseStyle
# Id
# 13         Sawyer     1Story
# 51        Gilbert     2Story
# 96        Gilbert     2Story
# 127       NPkVill     1Story
# 250       ClearCr     1.5Fin
# 308        IDOTRR     1.5Fin
# 365        NWAmes     2Story
# 385       ClearCr     2Story
# 422        NWAmes     1Story
# 542       NoRidge     2Story
# 612        NWAmes       SLvl
# 661        NWAmes     2Story
# 688       Somerst     2Story
# 707       ClearCr     1Story
# 829       ClearCr     2Story
# 869       Gilbert     2Story
# 1007        NAmes     1Story
# 1058      NoRidge     2Story
# 1085      Gilbert     2Story
# 1165      Veenker       SLvl
# 1181       Timber     2Story
# 1347       NWAmes     1Story
# 1349      SawyerW     1Story
# 1432      NPkVill     1Story
# 1696      Gilbert     2Story
# 1834      OldTown     2Story
# 1937      Gilbert     2Story
# 1942      Gilbert     2Story
# 1958       NWAmes     2Story
# 1997      NoRidge     2Story
# 2129       IDOTRR     1Story
# 2156      SawyerW     2Story
# 2164      SawyerW       SLvl
# 2223      Mitchel     1Story
# 2251       IDOTRR     2.5Unf
# 2358      SawyerW     2Story
# 2536      CollgCr     2Story
# 2612      Mitchel     1Story
# 2635       NWAmes     SFoyer
# 2678      Gilbert     2Story

# %% [markdown]
# ### Encode Categorical Data

# %% [markdown]
# ### Normalization

# %% [markdown]
# ## EDA

# %% [markdown]
# ## Feature Engineering

# %% [markdown]
# ## Simple Model Generation and Comparison
